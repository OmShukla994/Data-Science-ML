# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the Data and Selecting the Features

# %% [markdown]
# ### Import Data

# %%
loan_data_inputs_train = pd.read_csv(r'C:\Users\om\Downloads\CRM\loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv(r'C:\Users\om\Downloads\CRM\loan_data_targets_train.csv', index_col = 0)
loan_data_inputs_test = pd.read_csv(r'C:\Users\om\Downloads\CRM\loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test = pd.read_csv(r'C:\Users\om\Downloads\CRM\loan_data_targets_test.csv', index_col = 0)

# %%
#loan_data_targets_train = pd.read_csv(r'C:\Users\om\Downloads\CRM\loan_data_targets_train.csv', index_col = 0, header = None)
#loan_data_targets_test = pd.read_csv(r'C:\Users\om\Downloads\CRM\loan_data_targets_test.csv', index_col = 0, header = None)

# %% [markdown]
# ### Explore Data

# %%
loan_data_inputs_train.head()
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 427211      427211  12796369   14818505      24000        24000
# 206088      206088   1439740    1691948      10000        10000
# 136020      136020   5214749    6556909      20425        20425
# 412305      412305  13827698   15890016      17200        17200
# 36159        36159    422455     496525       8400         8400
#
#         funded_amnt_inv        term  int_rate  installment grade  ...  \
# 427211          24000.0   36 months      8.90       762.08     A  ...
# 206088          10000.0   36 months     14.33       343.39     C  ...
# 136020          20425.0   36 months      8.90       648.56     A  ...
# 412305          17200.0   36 months     16.59       609.73     D  ...
# 36159            7450.0   36 months     12.84       282.40     C  ...
#
#        dti:21.7-22.4 dti:22.4-35 dti:>35 mths_since_last_record:Missing  \
# 427211             1           0       0                              1
# 206088             0           0       0                              1
# 136020             0           0       0                              1
# 412305             0           0       0                              1
# 36159              0           1       0                              1
#
#         mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                           0                           0
# 206088                           0                           0
# 136020                           0                           0
# 412305                           0                           0
# 36159                            0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>86
# 427211                            0                          0
# 206088                            0                          0
# 136020                            0                          0
# 412305                            0                          0
# 36159                             0                          0
#
# [5 rows x 324 columns]

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         0
# 36159          0

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 324)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 207)

# %%
loan_data_targets_test.shape
# Out:
# (93257, 1)

# %% [markdown]
# ### Selecting the Features

# %%
# Here we select a limited set of input variables in a new dataframe.
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86'                                                         
]]

# %%
# Here we store the names of the reference category dummy variables in a list.
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
# From the dataframe with input variables, we drop the variables with variable names in the list with reference categories. 
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  dti:22.4-35  mths_since_last_delinq:Missing  \
# 427211              0  ...            0                               1
# 206088              0  ...            0                               0
# 136020              0  ...            0                               0
# 412305              0  ...            0                               0
# 36159               0  ...            1                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
# [5 rows x 103 columns]

# %% [markdown]
# # PD Model Estimation

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()
# We create an instance of an object from the 'LogisticRegression' class.

# %%
pd.options.display.max_rows = None
# Sets the pandas dataframe options to display all columns/ rows.

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Estimates the coefficients of the object from the 'LogisticRegression' class
# with inputs (independent variables) contained in the first dataframe
# and targets (dependent variables) contained in the second dataframe.
# Out:
# C:\Users\om\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\om\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.intercept_
# Displays the intercept contain in the estimated ("fitted") object from the 'LogisticRegression' class.
# Out:
# array([-1.03329647])

# %%
reg.coef_
# Displays the coefficients contained in the estimated ("fitted") object from the 'LogisticRegression' class.
# Out:
# array([[ 1.18947967,  0.91365405,  0.71396165,  0.52149552,  0.33996639,
#          0.1485862 ,  0.09173828,  0.10743324,  0.03769037,  0.05992376,
#          0.0597788 ,  0.06318506,  0.07967564,  0.13744513,  0.10045098,
#          0.18640189,  0.25039862,  0.22459505,  0.26386236,  0.32166451,
#          0.52021045,  0.08600444, -0.01226998,  0.2951808 ,  0.19281732,
#          0.20469603,  0.25802839,  0.05489048,  0.07643319,  0.09668645,
#          0.12419185,  0.08934102,  0.05989388,  0.12146446,  1.09809638,
#          0.89494385,  0.79734338,  0.5953832 ,  0.432472  ,  0.18758517,
#         -0.05051119,  0.83089459,  0.53911747,  0.29140805,  0.10482551,
#          0.05215983,  0.03602722,  0.07606813,  0.11690593,  0.12337498,
#          0.05580213,  0.02846676,  0.53607175,  0.39312095,  0.18129403,
#          0.01051464, -0.08638836, -0.11334595, -0.12899854, -0.12074845,
#         -0.11125746, -0.19057791,  0.12282572,  0.15409876, -0.02161867,
#          0.0333543 ,  0.26091587,  0.04126798,  0.00920871,  0.00678723,
#          0.01953947,  0.04116699,  0.06630937,  0.21953047, -0.05816707,
#          0.01078979,  0.10973466,  0.17906069,  0.2558593 ,  0.32873085,
#          0.40637758,  0.42454519,  0.50198376,  0.59278311,  0.51547614,
#          0.15792836,  0.27748255,  0.31499445,  0.25548746,  0.18005796,
#          0.08257094,  0.06866193,  0.03707593, -0.00305537,  0.13944608,
#          0.19357396,  0.21632145,  0.16865157,  0.10090426,  0.19185581,
#          0.12902665,  0.28506803, -0.04581985]])

# %%
feature_name = inputs_train.columns.values
# Stores the names of the columns of a dataframe in a variable.

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
# Creates a dataframe with a column titled 'Feature name' and row values contained in the 'feature_name' variable.
summary_table['Coefficients'] = np.transpose(reg.coef_)
# Creates a new column in the dataframe, called 'Coefficients',
# with row values the transposed coefficients from the 'LogisticRegression' object.
summary_table.index = summary_table.index + 1
# Increases the index of every row of the dataframe with 1.
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
# Assigns values of the row with index 0 of the dataframe.
summary_table = summary_table.sort_index()
# Sorts the dataframe by index.
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.033296
# 1                                grade:A      1.189480
# 2                                grade:B      0.913654
# 3                                grade:C      0.713962
# 4                                grade:D      0.521496
# 5                                grade:E      0.339966
# 6                                grade:F      0.148586
# 7                     home_ownership:OWN      0.091738
# 8                home_ownership:MORTGAGE      0.107433
# 9                       addr_state:NM_VA      0.037690
# 10                         addr_state:NY      0.059924
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.059779
# 12                         addr_state:CA      0.063185
# 13                addr_state:UT_KY_AZ_NJ      0.079676
# 14             addr_state:AR_MI_PA_OH_MN      0.137445
# 15             addr_state:RI_MA_DE_SD_IN      0.100451
# 16                   addr_state:GA_WA_OR      0.186402
# 17                      addr_state:WI_MT      0.250399
# 18                         addr_state:TX      0.224595
# 19                      addr_state:IL_CT      0.263862
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321665
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520210
# 22      verification_status:Not Verified      0.086004
# 23   verification_status:Source Verified     -0.012270
# 24                   purpose:credit_card      0.295181
# 25            purpose:debt_consolidation      0.192817
# 26            purpose:oth__med__vacation      0.204696
# 27   purpose:major_purch__car__home_impr      0.258028
# 28                 initial_list_status:w      0.054890
# 29                               term:36      0.076433
# 30                          emp_length:1      0.096686
# 31                        emp_length:2-4      0.124192
# 32                        emp_length:5-6      0.089341
# 33                        emp_length:7-9      0.059894
# 34                         emp_length:10      0.121464
# 35                mths_since_issue_d:<38      1.098096
# 36              mths_since_issue_d:38-39      0.894944
# 37              mths_since_issue_d:40-41      0.797343
# 38              mths_since_issue_d:42-48      0.595383
# 39              mths_since_issue_d:49-52      0.432472
# 40              mths_since_issue_d:53-64      0.187585
# 41              mths_since_issue_d:65-84     -0.050511
# 42                       int_rate:<9.548      0.830895
# 43                 int_rate:9.548-12.025      0.539117
# 44                 int_rate:12.025-15.74      0.291408
# 45                 int_rate:15.74-20.281      0.104826
# 46   mths_since_earliest_cr_line:141-164      0.052160
# 47   mths_since_earliest_cr_line:165-247      0.036027
# 48   mths_since_earliest_cr_line:248-270      0.076068
# 49   mths_since_earliest_cr_line:271-352      0.116906
# 50      mths_since_earliest_cr_line:>352      0.123375
# 51                         delinq_2yrs:0      0.055802
# 52                       delinq_2yrs:1-3      0.028467
# 53                      inq_last_6mths:0      0.536072
# 54                    inq_last_6mths:1-2      0.393121
# 55                    inq_last_6mths:3-6      0.181294
# 56                          open_acc:1-3      0.010515
# 57                         open_acc:4-12     -0.086388
# 58                        open_acc:13-17     -0.113346
# 59                        open_acc:18-22     -0.128999
# 60                        open_acc:23-25     -0.120748
# 61                        open_acc:26-30     -0.111257
# 62                         open_acc:>=31     -0.190578
# 63                           pub_rec:3-4      0.122826
# 64                           pub_rec:>=5      0.154099
# 65                       total_acc:28-51     -0.021619
# 66                        total_acc:>=52      0.033354
# 67                    acc_now_delinq:>=1      0.260916
# 68               total_rev_hi_lim:5K-10K      0.041268
# 69              total_rev_hi_lim:10K-20K      0.009209
# 70              total_rev_hi_lim:20K-30K      0.006787
# 71              total_rev_hi_lim:30K-40K      0.019539
# 72              total_rev_hi_lim:40K-55K      0.041167
# 73              total_rev_hi_lim:55K-95K      0.066309
# 74                 total_rev_hi_lim:>95K      0.219530
# 75                    annual_inc:20K-30K     -0.058167
# 76                    annual_inc:30K-40K      0.010790
# 77                    annual_inc:40K-50K      0.109735
# 78                    annual_inc:50K-60K      0.179061
# 79                    annual_inc:60K-70K      0.255859
# 80                    annual_inc:70K-80K      0.328731
# 81                    annual_inc:80K-90K      0.406378
# 82                   annual_inc:90K-100K      0.424545
# 83                  annual_inc:100K-120K      0.501984
# 84                  annual_inc:120K-140K      0.592783
# 85                      annual_inc:>140K      0.515476
# 86                             dti:<=1.4      0.157928
# 87                           dti:1.4-3.5      0.277483
# 88                           dti:3.5-7.7      0.314994
# 89                          dti:7.7-10.5      0.255487
# 90                         dti:10.5-16.1      0.180058
# 91                         dti:16.1-20.3      0.082571
# 92                         dti:20.3-21.7      0.068662
# 93                         dti:21.7-22.4      0.037076
# 94                           dti:22.4-35     -0.003055
# 95        mths_since_last_delinq:Missing      0.139446
# 96           mths_since_last_delinq:4-30      0.193574
# 97          mths_since_last_delinq:31-56      0.216321
# 98           mths_since_last_delinq:>=57      0.168652
# 99        mths_since_last_record:Missing      0.100904
# 100          mths_since_last_record:3-20      0.191856
# 101         mths_since_last_record:21-31      0.129027
# 102         mths_since_last_record:32-80      0.285068
# 103         mths_since_last_record:81-86     -0.045820

# %% [markdown]
# ## Build a Logistic Regression Model with P-Values

# %%
# P values for sklearn logistic regression.

# Class to display p-values for logistic regression in sklearn.

from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):#,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)#,**args)

    def fit(self,X,y):
        self.model.fit(X,y)
        
        #### Get p-values for the fitted model ####
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X) ## Fisher Information Matrix
        Cramer_Rao = np.linalg.inv(F_ij) ## Inverse Information Matrix
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates # z-score for eaach model coefficient
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores] ### two tailed test for p-values
        
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()
# We create an instance of an object from the newly created 'LogisticRegression_with_p_values()' class.

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Estimates the coefficients of the object from the 'LogisticRegression' class
# with inputs (independent variables) contained in the first dataframe
# and targets (dependent variables) contained in the second dataframe.
# Out:
# C:\Users\om\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\om\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.033296
# 1                                grade:A      1.189480
# 2                                grade:B      0.913654
# 3                                grade:C      0.713962
# 4                                grade:D      0.521496
# 5                                grade:E      0.339966
# 6                                grade:F      0.148586
# 7                     home_ownership:OWN      0.091738
# 8                home_ownership:MORTGAGE      0.107433
# 9                       addr_state:NM_VA      0.037690
# 10                         addr_state:NY      0.059924
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.059779
# 12                         addr_state:CA      0.063185
# 13                addr_state:UT_KY_AZ_NJ      0.079676
# 14             addr_state:AR_MI_PA_OH_MN      0.137445
# 15             addr_state:RI_MA_DE_SD_IN      0.100451
# 16                   addr_state:GA_WA_OR      0.186402
# 17                      addr_state:WI_MT      0.250399
# 18                         addr_state:TX      0.224595
# 19                      addr_state:IL_CT      0.263862
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321665
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520210
# 22      verification_status:Not Verified      0.086004
# 23   verification_status:Source Verified     -0.012270
# 24                   purpose:credit_card      0.295181
# 25            purpose:debt_consolidation      0.192817
# 26            purpose:oth__med__vacation      0.204696
# 27   purpose:major_purch__car__home_impr      0.258028
# 28                 initial_list_status:w      0.054890
# 29                               term:36      0.076433
# 30                          emp_length:1      0.096686
# 31                        emp_length:2-4      0.124192
# 32                        emp_length:5-6      0.089341
# 33                        emp_length:7-9      0.059894
# 34                         emp_length:10      0.121464
# 35                mths_since_issue_d:<38      1.098096
# 36              mths_since_issue_d:38-39      0.894944
# 37              mths_since_issue_d:40-41      0.797343
# 38              mths_since_issue_d:42-48      0.595383
# 39              mths_since_issue_d:49-52      0.432472
# 40              mths_since_issue_d:53-64      0.187585
# 41              mths_since_issue_d:65-84     -0.050511
# 42                       int_rate:<9.548      0.830895
# 43                 int_rate:9.548-12.025      0.539117
# 44                 int_rate:12.025-15.74      0.291408
# 45                 int_rate:15.74-20.281      0.104826
# 46   mths_since_earliest_cr_line:141-164      0.052160
# 47   mths_since_earliest_cr_line:165-247      0.036027
# 48   mths_since_earliest_cr_line:248-270      0.076068
# 49   mths_since_earliest_cr_line:271-352      0.116906
# 50      mths_since_earliest_cr_line:>352      0.123375
# 51                         delinq_2yrs:0      0.055802
# 52                       delinq_2yrs:1-3      0.028467
# 53                      inq_last_6mths:0      0.536072
# 54                    inq_last_6mths:1-2      0.393121
# 55                    inq_last_6mths:3-6      0.181294
# 56                          open_acc:1-3      0.010515
# 57                         open_acc:4-12     -0.086388
# 58                        open_acc:13-17     -0.113346
# 59                        open_acc:18-22     -0.128999
# 60                        open_acc:23-25     -0.120748
# 61                        open_acc:26-30     -0.111257
# 62                         open_acc:>=31     -0.190578
# 63                           pub_rec:3-4      0.122826
# 64                           pub_rec:>=5      0.154099
# 65                       total_acc:28-51     -0.021619
# 66                        total_acc:>=52      0.033354
# 67                    acc_now_delinq:>=1      0.260916
# 68               total_rev_hi_lim:5K-10K      0.041268
# 69              total_rev_hi_lim:10K-20K      0.009209
# 70              total_rev_hi_lim:20K-30K      0.006787
# 71              total_rev_hi_lim:30K-40K      0.019539
# 72              total_rev_hi_lim:40K-55K      0.041167
# 73              total_rev_hi_lim:55K-95K      0.066309
# 74                 total_rev_hi_lim:>95K      0.219530
# 75                    annual_inc:20K-30K     -0.058167
# 76                    annual_inc:30K-40K      0.010790
# 77                    annual_inc:40K-50K      0.109735
# 78                    annual_inc:50K-60K      0.179061
# 79                    annual_inc:60K-70K      0.255859
# 80                    annual_inc:70K-80K      0.328731
# 81                    annual_inc:80K-90K      0.406378
# 82                   annual_inc:90K-100K      0.424545
# 83                  annual_inc:100K-120K      0.501984
# 84                  annual_inc:120K-140K      0.592783
# 85                      annual_inc:>140K      0.515476
# 86                             dti:<=1.4      0.157928
# 87                           dti:1.4-3.5      0.277483
# 88                           dti:3.5-7.7      0.314994
# 89                          dti:7.7-10.5      0.255487
# 90                         dti:10.5-16.1      0.180058
# 91                         dti:16.1-20.3      0.082571
# 92                         dti:20.3-21.7      0.068662
# 93                         dti:21.7-22.4      0.037076
# 94                           dti:22.4-35     -0.003055
# 95        mths_since_last_delinq:Missing      0.139446
# 96           mths_since_last_delinq:4-30      0.193574
# 97          mths_since_last_delinq:31-56      0.216321
# 98           mths_since_last_delinq:>=57      0.168652
# 99        mths_since_last_record:Missing      0.100904
# 100          mths_since_last_record:3-20      0.191856
# 101         mths_since_last_record:21-31      0.129027
# 102         mths_since_last_record:32-80      0.285068
# 103         mths_since_last_record:81-86     -0.045820

# %%
# This is a list.
p_values = reg.p_values
# We take the result of the newly added method 'p_values' and store it in a variable 'p_values'.

# %%
# Add the intercept for completeness.
p_values = np.append(np.nan, np.array(p_values))
# We add the value 'NaN' in the beginning of the variable with p-values.

# %%
summary_table['p_values'] = p_values
# In the 'summary_table' dataframe, we add a new column, called 'p_values', containing the values from the 'p_values' variable.

# %%
summary_table
# Out:
#                             Feature name  Coefficients       p_values
# 0                              Intercept     -1.033296            NaN
# 1                                grade:A      1.189480   8.857348e-40
# 2                                grade:B      0.913654   8.361343e-51
# 3                                grade:C      0.713962   1.491336e-36
# 4                                grade:D      0.521496   2.755833e-22
# 5                                grade:E      0.339966   1.485923e-12
# 6                                grade:F      0.148586   3.020858e-03
# 7                     home_ownership:OWN      0.091738   5.441530e-06
# 8                home_ownership:MORTGAGE      0.107433   2.672658e-17
# 9                       addr_state:NM_VA      0.037690   2.398198e-01
# 10                         addr_state:NY      0.059924   1.361422e-02
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.059779   9.993119e-03
# 12                         addr_state:CA      0.063185   2.931099e-03
# 13                addr_state:UT_KY_AZ_NJ      0.079676   1.409352e-03
# 14             addr_state:AR_MI_PA_OH_MN      0.137445   1.139620e-09
# 15             addr_state:RI_MA_DE_SD_IN      0.100451   7.716630e-04
# 16                   addr_state:GA_WA_OR      0.186402   3.012397e-12
# 17                      addr_state:WI_MT      0.250399   1.549523e-07
# 18                         addr_state:TX      0.224595   6.006123e-18
# 19                      addr_state:IL_CT      0.263862   1.895868e-19
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.321665   2.018901e-25
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.520210   1.329514e-22
# 22      verification_status:Not Verified      0.086004   4.665512e-09
# 23   verification_status:Source Verified     -0.012270   3.624514e-01
# 24                   purpose:credit_card      0.295181   3.718124e-25
# 25            purpose:debt_consolidation      0.192817   1.904470e-13
# 26            purpose:oth__med__vacation      0.204696   5.901758e-11
# 27   purpose:major_purch__car__home_impr      0.258028   2.090254e-16
# 28                 initial_list_status:w      0.054890   2.626062e-05
# 29                               term:36      0.076433   7.045184e-08
# 30                          emp_length:1      0.096686   1.950140e-04
# 31                        emp_length:2-4      0.124192   4.915172e-11
# 32                        emp_length:5-6      0.089341   3.026275e-05
# 33                        emp_length:7-9      0.059894   4.002747e-03
# 34                         emp_length:10      0.121464   4.571181e-11
# 35                mths_since_issue_d:<38      1.098096  3.405991e-183
# 36              mths_since_issue_d:38-39      0.894944  1.876853e-152
# 37              mths_since_issue_d:40-41      0.797343  1.803346e-127
# 38              mths_since_issue_d:42-48      0.595383   4.900798e-91
# 39              mths_since_issue_d:49-52      0.432472   5.710862e-43
# 40              mths_since_issue_d:53-64      0.187585   2.372223e-10
# 41              mths_since_issue_d:65-84     -0.050511   7.933458e-02
# 42                       int_rate:<9.548      0.830895   3.709032e-28
# 43                 int_rate:9.548-12.025      0.539117   2.442881e-33
# 44                 int_rate:12.025-15.74      0.291408   2.774435e-15
# 45                 int_rate:15.74-20.281      0.104826   3.161121e-04
# 46   mths_since_earliest_cr_line:141-164      0.052160   3.678206e-02
# 47   mths_since_earliest_cr_line:165-247      0.036027   7.709893e-02
# 48   mths_since_earliest_cr_line:248-270      0.076068   4.251793e-03
# 49   mths_since_earliest_cr_line:271-352      0.116906   1.016147e-06
# 50      mths_since_earliest_cr_line:>352      0.123375   5.104945e-06
# 51                         delinq_2yrs:0      0.055802   3.281571e-01
# 52                       delinq_2yrs:1-3      0.028467   5.966676e-01
# 53                      inq_last_6mths:0      0.536072   4.341579e-06
# 54                    inq_last_6mths:1-2      0.393121   7.417758e-04
# 55                    inq_last_6mths:3-6      0.181294   1.213750e-01
# 56                          open_acc:1-3      0.010515   9.481214e-01
# 57                         open_acc:4-12     -0.086388   5.831274e-01
# 58                        open_acc:13-17     -0.113346   4.723800e-01
# 59                        open_acc:18-22     -0.128999   4.164679e-01
# 60                        open_acc:23-25     -0.120748   4.603847e-01
# 61                        open_acc:26-30     -0.111257   5.097807e-01
# 62                         open_acc:>=31     -0.190578   2.984751e-01
# 63                           pub_rec:3-4      0.122826   1.951249e-01
# 64                           pub_rec:>=5      0.154099   4.199353e-01
# 65                       total_acc:28-51     -0.021619   1.279775e-01
# 66                        total_acc:>=52      0.033354   4.024441e-01
# 67                    acc_now_delinq:>=1      0.260916   1.319918e-02
# 68               total_rev_hi_lim:5K-10K      0.041268   9.369721e-02
# 69              total_rev_hi_lim:10K-20K      0.009209   6.996378e-01
# 70              total_rev_hi_lim:20K-30K      0.006787   7.958348e-01
# 71              total_rev_hi_lim:30K-40K      0.019539   5.069031e-01
# 72              total_rev_hi_lim:40K-55K      0.041167   2.004117e-01
# 73              total_rev_hi_lim:55K-95K      0.066309   6.571757e-02
# 74                 total_rev_hi_lim:>95K      0.219530   1.080990e-04
# 75                    annual_inc:20K-30K     -0.058167   1.748488e-01
# 76                    annual_inc:30K-40K      0.010790   7.942431e-01
# 77                    annual_inc:40K-50K      0.109735   8.058038e-03
# 78                    annual_inc:50K-60K      0.179061   2.016704e-05
# 79                    annual_inc:60K-70K      0.255859   2.724115e-09
# 80                    annual_inc:70K-80K      0.328731   7.254542e-14
# 81                    annual_inc:80K-90K      0.406378   6.596693e-19
# 82                   annual_inc:90K-100K      0.424545   3.153436e-19
# 83                  annual_inc:100K-120K      0.501984   1.532736e-26
# 84                  annual_inc:120K-140K      0.592783   1.053160e-28
# 85                      annual_inc:>140K      0.515476   2.125128e-25
# 86                             dti:<=1.4      0.157928   7.639984e-02
# 87                           dti:1.4-3.5      0.277483   2.404843e-04
# 88                           dti:3.5-7.7      0.314994   1.939864e-06
# 89                          dti:7.7-10.5      0.255487   9.861826e-05
# 90                         dti:10.5-16.1      0.180058   4.674000e-03
# 91                         dti:16.1-20.3      0.082571   1.943486e-01
# 92                         dti:20.3-21.7      0.068662   2.984261e-01
# 93                         dti:21.7-22.4      0.037076   5.952965e-01
# 94                           dti:22.4-35     -0.003055   9.612477e-01
# 95        mths_since_last_delinq:Missing      0.139446   8.921280e-03
# 96           mths_since_last_delinq:4-30      0.193574   1.045160e-04
# 97          mths_since_last_delinq:31-56      0.216321   7.721078e-05
# 98           mths_since_last_delinq:>=57      0.168652   2.570528e-03
# 99        mths_since_last_record:Missing      0.100904   5.218632e-06
# 100          mths_since_last_record:3-20      0.191856   4.476376e-02
# 101         mths_since_last_record:21-31      0.129027   1.129817e-01
# 102         mths_since_last_record:32-80      0.285068   7.629820e-18
# 103         mths_since_last_record:81-86     -0.045820   4.837721e-01

# %%
# We are going to remove some features, the coefficients for all or almost all of the dummy variables for which,
# are not statistically significant.

# We do that by specifying another list of dummy variables as reference categories, and a list of variables to remove.
# Then, we are going to drop the two datasets from the original list of dummy variables.

# Variables
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86'
]]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  dti:22.4-35  mths_since_last_delinq:Missing  \
# 427211              0  ...            0                               1
# 206088              0  ...            0                               0
# 136020              0  ...            0                               0
# 412305              0  ...            0                               0
# 36159               0  ...            1                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
# [5 rows x 83 columns]

# %%
# Here we run a new model.
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\om\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\om\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = inputs_train.columns.values

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -1.286571
# 1                               grade:A      1.155580
# 2                               grade:B      0.912933
# 3                               grade:C      0.716380
# 4                               grade:D      0.525330
# 5                               grade:E      0.342265
# 6                               grade:F      0.152201
# 7                    home_ownership:OWN      0.093714
# 8               home_ownership:MORTGAGE      0.106218
# 9                      addr_state:NM_VA      0.036098
# 10                        addr_state:NY      0.057793
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12                        addr_state:CA      0.063949
# 13               addr_state:UT_KY_AZ_NJ      0.078983
# 14            addr_state:AR_MI_PA_OH_MN      0.136948
# 15            addr_state:RI_MA_DE_SD_IN      0.101655
# 16                  addr_state:GA_WA_OR      0.185746
# 17                     addr_state:WI_MT      0.240456
# 18                        addr_state:TX      0.222863
# 19                     addr_state:IL_CT      0.262768
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22     verification_status:Not Verified      0.084434
# 23  verification_status:Source Verified     -0.010560
# 24                  purpose:credit_card      0.300415
# 25           purpose:debt_consolidation      0.197168
# 26           purpose:oth__med__vacation      0.213265
# 27  purpose:major_purch__car__home_impr      0.265546
# 28                initial_list_status:w      0.054820
# 29                              term:36      0.078657
# 30                         emp_length:1      0.099199
# 31                       emp_length:2-4      0.126174
# 32                       emp_length:5-6      0.091429
# 33                       emp_length:7-9      0.061589
# 34                        emp_length:10      0.125336
# 35               mths_since_issue_d:<38      1.091989
# 36             mths_since_issue_d:38-39      0.890632
# 37             mths_since_issue_d:40-41      0.788919
# 38             mths_since_issue_d:42-48      0.587156
# 39             mths_since_issue_d:49-52      0.425053
# 40             mths_since_issue_d:53-64      0.178658
# 41             mths_since_issue_d:65-84     -0.060625
# 42                      int_rate:<9.548      0.867403
# 43                int_rate:9.548-12.025      0.540435
# 44                int_rate:12.025-15.74      0.291230
# 45                int_rate:15.74-20.281      0.103116
# 46  mths_since_earliest_cr_line:141-164      0.056439
# 47  mths_since_earliest_cr_line:165-247      0.038175
# 48  mths_since_earliest_cr_line:248-270      0.080625
# 49  mths_since_earliest_cr_line:271-352      0.122839
# 50     mths_since_earliest_cr_line:>352      0.131429
# 51                     inq_last_6mths:0      0.694464
# 52                   inq_last_6mths:1-2      0.547345
# 53                   inq_last_6mths:3-6      0.336631
# 54                   acc_now_delinq:>=1      0.235451
# 55                   annual_inc:20K-30K     -0.068940
# 56                   annual_inc:30K-40K     -0.005534
# 57                   annual_inc:40K-50K      0.089310
# 58                   annual_inc:50K-60K      0.156335
# 59                   annual_inc:60K-70K      0.231736
# 60                   annual_inc:70K-80K      0.306246
# 61                   annual_inc:80K-90K      0.380309
# 62                  annual_inc:90K-100K      0.400762
# 63                 annual_inc:100K-120K      0.479392
# 64                 annual_inc:120K-140K      0.577041
# 65                     annual_inc:>140K      0.505299
# 66                            dti:<=1.4      0.252541
# 67                          dti:1.4-3.5      0.371493
# 68                          dti:3.5-7.7      0.389216
# 69                         dti:7.7-10.5      0.324627
# 70                        dti:10.5-16.1      0.245253
# 71                        dti:16.1-20.3      0.143907
# 72                        dti:20.3-21.7      0.132742
# 73                        dti:21.7-22.4      0.097492
# 74                          dti:22.4-35      0.054606
# 75       mths_since_last_delinq:Missing      0.167526
# 76          mths_since_last_delinq:4-30      0.192266
# 77         mths_since_last_delinq:31-56      0.239033
# 78          mths_since_last_delinq:>=57      0.191772
# 79       mths_since_last_record:Missing      0.102726
# 80          mths_since_last_record:3-20      0.212815
# 81         mths_since_last_record:21-31      0.135718
# 82         mths_since_last_record:32-80      0.286681
# 83         mths_since_last_record:81-86     -0.049878

# %%
# We add the 'p_values' here, just as we did before.
p_values = reg2.p_values
p_values = np.append(np.nan,np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Here we get the results for our final PD model.
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.286581            NaN
# 1                               grade:A      1.155575   2.053151e-37
# 2                               grade:B      0.912937   2.734551e-51
# 3                               grade:C      0.716384   2.227673e-37
# 4                               grade:D      0.525335   4.195039e-23
# 5                               grade:E      0.342270   3.047127e-13
# 6                               grade:F      0.152206   1.812746e-03
# 7                    home_ownership:OWN      0.093715   3.282686e-06
# 8               home_ownership:MORTGAGE      0.106218   4.430035e-17
# 9                      addr_state:NM_VA      0.036096   2.594563e-01
# 10                        addr_state:NY      0.057792   1.698795e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059828   9.724893e-03
# 12                        addr_state:CA      0.063948   2.537431e-03
# 13               addr_state:UT_KY_AZ_NJ      0.078983   1.513949e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.136948   1.151395e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.101654   6.561181e-04
# 16                  addr_state:GA_WA_OR      0.185745   3.201015e-12
# 17                     addr_state:WI_MT      0.240448   4.237243e-07
# 18                        addr_state:TX      0.222863   9.250597e-18
# 19                     addr_state:IL_CT      0.262768   2.217471e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.320930   2.185070e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.524192   6.879322e-23
# 22     verification_status:Not Verified      0.084433   7.094445e-09
# 23  verification_status:Source Verified     -0.010561   4.316556e-01
# 24                  purpose:credit_card      0.300414   2.050721e-26
# 25           purpose:debt_consolidation      0.197168   3.171457e-14
# 26           purpose:oth__med__vacation      0.213263   6.770162e-12
# 27  purpose:major_purch__car__home_impr      0.265544   1.652992e-17
# 28                initial_list_status:w      0.054820   2.676000e-05
# 29                              term:36      0.078658   1.813395e-08
# 30                         emp_length:1      0.099201   1.301889e-04
# 31                       emp_length:2-4      0.126174   2.247984e-11
# 32                       emp_length:5-6      0.091429   1.923740e-05
# 33                       emp_length:7-9      0.061589   3.054427e-03
# 34                        emp_length:10      0.125336   1.035176e-11
# 35               mths_since_issue_d:<38      1.091989  7.309730e-189
# 36             mths_since_issue_d:38-39      0.890632  1.158679e-158
# 37             mths_since_issue_d:40-41      0.788919  1.874492e-131
# 38             mths_since_issue_d:42-48      0.587156   4.829121e-94
# 39             mths_since_issue_d:49-52      0.425051   8.028556e-44
# 40             mths_since_issue_d:53-64      0.178657   5.216586e-10
# 41             mths_since_issue_d:65-84     -0.060626   3.499801e-02
# 42                      int_rate:<9.548      0.867408   3.711389e-30
# 43                int_rate:9.548-12.025      0.540434   7.712966e-34
# 44                int_rate:12.025-15.74      0.291227   1.983984e-15
# 45                int_rate:15.74-20.281      0.103116   3.683647e-04
# 46  mths_since_earliest_cr_line:141-164      0.056442   2.317276e-02
# 47  mths_since_earliest_cr_line:165-247      0.038177   5.686268e-02
# 48  mths_since_earliest_cr_line:248-270      0.080627   2.092129e-03
# 49  mths_since_earliest_cr_line:271-352      0.122842   1.497795e-07
# 50     mths_since_earliest_cr_line:>352      0.131431   6.942234e-07
# 51                     inq_last_6mths:0      0.694465   8.173918e-18
# 52                   inq_last_6mths:1-2      0.547347   1.183215e-11
# 53                   inq_last_6mths:3-6      0.336633   3.563960e-05
# 54                   acc_now_delinq:>=1      0.235446   2.326600e-02
# 55                   annual_inc:20K-30K     -0.068938   9.947094e-02
# 56                   annual_inc:30K-40K     -0.005534   8.904933e-01
# 57                   annual_inc:40K-50K      0.089310   2.606752e-02
# 58                   annual_inc:50K-60K      0.156335   1.207763e-04
# 59                   annual_inc:60K-70K      0.231736   2.552412e-08
# 60                   annual_inc:70K-80K      0.306245   5.401247e-13
# 61                   annual_inc:80K-90K      0.380310   7.969314e-18
# 62                  annual_inc:90K-100K      0.400761   2.166428e-18
# 63                 annual_inc:100K-120K      0.479390   4.983292e-26
# 64                 annual_inc:120K-140K      0.577043   7.344389e-29
# 65                     annual_inc:>140K      0.505300   1.348325e-26
# 66                            dti:<=1.4      0.252541   2.330263e-03
# 67                          dti:1.4-3.5      0.371498   8.815076e-08
# 68                          dti:3.5-7.7      0.389217   6.679156e-11
# 69                         dti:7.7-10.5      0.324629   4.307500e-08
# 70                        dti:10.5-16.1      0.245253   1.825753e-05
# 71                        dti:16.1-20.3      0.143908   1.207536e-02
# 72                        dti:20.3-21.7      0.132742   2.711119e-02
# 73                        dti:21.7-22.4      0.097493   1.288965e-01
# 74                          dti:22.4-35      0.054606   3.354190e-01
# 75       mths_since_last_delinq:Missing      0.167528   3.994552e-04
# 76          mths_since_last_delinq:4-30      0.192268   6.767928e-05
# 77         mths_since_last_delinq:31-56      0.239035   1.034614e-06
# 78          mths_since_last_delinq:>=57      0.191773   1.379691e-04
# 79       mths_since_last_record:Missing      0.102727   2.756476e-06
# 80          mths_since_last_record:3-20      0.212815   2.358419e-02
# 81         mths_since_last_record:21-31      0.135717   9.164640e-02
# 82         mths_since_last_record:32-80      0.286679   1.250756e-18
# 83         mths_since_last_record:81-86     -0.049875   4.455325e-01

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))
# Here we export our model to a 'SAV' file with file name 'pd_model.sav'.

# %% [markdown]
# # PD Model Validation (Test)

# %% [markdown]
# ### Out-of-sample validation (test)

# %%
# Here, from the dataframe with inputs for testing, we keep the same variables that we used in our final PD model.
#NOTE: we are taking same train for now as test data is not clean

inputs_test_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86'
]]

# %%
# And here, in the list below, we keep the variable names for the reference categories,
# only for the variables we used in our final PD model.
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_test = inputs_test_with_ref_cat.drop(ref_categories, axis = 1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  dti:22.4-35  mths_since_last_delinq:Missing  \
# 427211              0  ...            0                               1
# 206088              0  ...            0                               0
# 136020              0  ...            0                               0
# 412305              0  ...            0                               0
# 36159               0  ...            1                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
# [5 rows x 83 columns]

# %%
y_hat_test = reg2.model.predict(inputs_test)
# Calculates the predicted values for the dependent variable (targets)
# based on the values of the independent variables (inputs) supplied as an argument.

# %%
y_hat_test
# This is an array of predicted discrete classess (in this case, 0s and 1s).
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)
# Calculates the predicted probability values for the dependent variable (targets)
# based on the values of the independent variables (inputs) supplied as an argument.

# %%
y_hat_test_proba
# This is an array of arrays of predicted class probabilities for all classes.
# In this case, the first value of every sub-array is the probability for the observation to belong to the first class, i.e. 0,
# and the second value is the probability for the observation to belong to the first class, i.e. 1.
# Out:
# array([[0.02945713, 0.97054287],
#        [0.09231379, 0.90768621],
#        [0.03748169, 0.96251831],
#        ...,
#        [0.07722292, 0.92277708],
#        [0.08398319, 0.91601681],
#        [0.08962839, 0.91037161]])

# %%
y_hat_test_proba[:][:,1]
# Here we take all the arrays in the array, and from each array, we take all rows, and only the element with index 1,
# that is, the second element.
# In other words, we take only the probabilities for being 1.
# Out:
# array([0.97054287, 0.90768621, 0.96251831, ..., 0.92277708, 0.91601681,
#        0.91037161])

# %%
y_hat_test_proba = y_hat_test_proba[: ][: , 1]
# We store these probabilities in a variable.

# %%
y_hat_test_proba
# This variable contains an array of probabilities of being 1.
# Out:
# array([0.97054287, 0.90768621, 0.96251831, ..., 0.92277708, 0.91601681,
#        0.91037161])

# %%
#taking train dataset for testing becoz test is not clean

loan_data_targets_test_temp = loan_data_targets_train

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)
# We reset the index of a dataframe.

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)
# Concatenates two dataframes.

# %%
df_actual_predicted_probs.shape
# Out:
# (373028, 2)

# %%
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']

# %%
df_actual_predicted_probs.index = loan_data_inputs_train.index
# Makes the index of one dataframe equal to the index of another dataframe.
#train dataset is taking becoz test is not clean

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba
# 427211                       1          0.970543
# 206088                       1          0.907686
# 136020                       1          0.962518
# 412305                       0          0.796068
# 36159                        0          0.797773

# %% [markdown]
# ### Accuracy and Area under the Curve

# %%
tr = 0.9
# We create a new column with an indicator,
# where every observation that has predicted probability greater than the threshold has a value of 1,
# and every observation that has predicted probability lower than the threshold has a value of 0.
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted'])
# Creates a cross-table where the actual values are displayed by rows and the predicted values by columns.
# This table is known as a Confusion Matrix.
# Out:
# Predicted       0       1
# Actual
# 0           29191   11587
# 1          143094  189156

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Here we divide each value of the table by the total number of observations,
# thus getting percentages, or, rates.
# Out:
# Predicted         0         1
# Actual
# 0          0.078254  0.031062
# 1          0.383601  0.507083

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Here we calculate Accuracy of the model, which is the sum of the diagonal rates.
# Out:
# 0.585336757562435

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Returns the Receiver Operating Characteristic (ROC) Curve from a set of actual values and their predicted probabilities.
# As a result, we get three arrays: the false positive rates, the true positive rates, and the thresholds.
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99992643, 0.99992643,
#         1.        ]),
#  array([0.00000000e+00, 3.00978179e-06, 1.23401053e-04, ...,
#         9.99996990e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([       inf, 0.99270378, 0.99081153, ..., 0.39821331, 0.39353225,
#         0.35399808]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Here we store each of the three arrays in a separate variable.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
# We plot the false positive rate along the x-axis and the true positive rate along the y-axis,
# thus plotting the ROC curve.
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
# We plot a seconary diagonal line, with dashed line style and black color.
plt.xlabel('False positive rate')
# We name the x-axis "False positive rate".
plt.ylabel('True positive rate')
# We name the x-axis "True positive rate".
plt.title('ROC curve')
# We name the graph "ROC curve".
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
AUROC = roc_auc_score(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Calculates the Area Under the Receiver Operating Characteristic Curve (AUROC)
# from a set of actual values and their predicted probabilities.
AUROC
# Out:
# 0.6975076029318543

# %% [markdown]
# ### Gini and Kolmogorov-Smirnov

# %%
df_actual_predicted_probs = df_actual_predicted_probs.sort_values('y_hat_test_proba')
# Sorts a dataframe by the values of a specific column.

# %%
df_actual_predicted_probs.head()
# Out:
#        loan_data_targets_test  y_hat_test_proba  y_hat_test
# 41422                       0          0.353998           0
# 39932                       0          0.381585           0
# 42398                       0          0.386908           0
# 41890                       1          0.393532           0
# 40593                       0          0.398213           0

# %%
df_actual_predicted_probs.tail()
# Out:
#         loan_data_targets_test  y_hat_test_proba  y_hat_test
# 311853                       1          0.992119           1
# 248134                       1          0.992256           1
# 238000                       1          0.992339           1
# 251159                       1          0.992446           1
# 243810                       1          0.992704           1

# %%
df_actual_predicted_probs = df_actual_predicted_probs.reset_index()
# We reset the index of a dataframe and overwrite it.

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test
# 0  41422                       0          0.353998           0
# 1  39932                       0          0.381585           0
# 2  42398                       0          0.386908           0
# 3  41890                       1          0.393532           0
# 4  40593                       0          0.398213           0

# %%
df_actual_predicted_probs['Cumulative N Population'] = df_actual_predicted_probs.index + 1
# We calculate the cumulative number of all observations.
# We use the new index for that. Since indexing in ython starts from 0, we add 1 to each index.
df_actual_predicted_probs['Cumulative N Good'] = df_actual_predicted_probs['loan_data_targets_test'].cumsum()
# We calculate cumulative number of 'good', which is the cumulative sum of the column with actual observations.
df_actual_predicted_probs['Cumulative N Bad'] = df_actual_predicted_probs['Cumulative N Population'] - df_actual_predicted_probs['loan_data_targets_test'].cumsum()
# We calculate cumulative number of 'bad', which is
# the difference between the cumulative number of all observations and cumulative number of 'good' for each row.

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0  41422                       0          0.353998           0
# 1  39932                       0          0.381585           0
# 2  42398                       0          0.386908           0
# 3  41890                       1          0.393532           0
# 4  40593                       0          0.398213           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad
# 0                        1                  0                 1
# 1                        2                  0                 2
# 2                        3                  0                 3
# 3                        4                  1                 3
# 4                        5                  1                 4

# %%
df_actual_predicted_probs['Cumulative Perc Population'] = df_actual_predicted_probs['Cumulative N Population'] / (df_actual_predicted_probs.shape[0])
# We calculate the cumulative percentage of all observations.
df_actual_predicted_probs['Cumulative Perc Good'] = df_actual_predicted_probs['Cumulative N Good'] / df_actual_predicted_probs['loan_data_targets_test'].sum()
# We calculate cumulative percentage of 'good'.
df_actual_predicted_probs['Cumulative Perc Bad'] = df_actual_predicted_probs['Cumulative N Bad'] / (df_actual_predicted_probs.shape[0] - df_actual_predicted_probs['loan_data_targets_test'].sum())
# We calculate the cumulative percentage of 'bad'.

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0  41422                       0          0.353998           0
# 1  39932                       0          0.381585           0
# 2  42398                       0          0.386908           0
# 3  41890                       1          0.393532           0
# 4  40593                       0          0.398213           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad  \
# 0                        1                  0                 1
# 1                        2                  0                 2
# 2                        3                  0                 3
# 3                        4                  1                 3
# 4                        5                  1                 4
#
#    Cumulative Perc Population  Cumulative Perc Good  Cumulative Perc Bad
# 0                    0.000003              0.000000             0.000025
# 1                    0.000005              0.000000             0.000049
# 2                    0.000008              0.000000             0.000074
# 3                    0.000011              0.000003             0.000074
# 4                    0.000013              0.000003             0.000098

# %%
df_actual_predicted_probs.tail()
# Out:
#          index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 373023  311853                       1          0.992119           1
# 373024  248134                       1          0.992256           1
# 373025  238000                       1          0.992339           1
# 373026  251159                       1          0.992446           1
# 373027  243810                       1          0.992704           1
#
#         Cumulative N Population  Cumulative N Good  Cumulative N Bad  \
# 373023                   373024             332246             40778
# 373024                   373025             332247             40778
# 373025                   373026             332248             40778
# 373026                   373027             332249             40778
# 373027                   373028             332250             40778
#
#         Cumulative Perc Population  Cumulative Perc Good  Cumulative Perc Bad
# 373023                    0.999989              0.999988                  1.0
# 373024                    0.999992              0.999991                  1.0
# 373025                    0.999995              0.999994                  1.0
# 373026                    0.999997              0.999997                  1.0
# 373027                    1.000000              1.000000                  1.0

# %%
# Plot Gini
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Bad'])
# We plot the cumulative percentage of all along the x-axis and the cumulative percentage 'good' along the y-axis,
# thus plotting the Gini curve.
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Population'], linestyle = '--', color = 'k')
# We plot a seconary diagonal line, with dashed line style and black color.
plt.xlabel('Cumulative % Population')
# We name the x-axis "Cumulative % Population".
plt.ylabel('Cumulative % Bad')
# We name the y-axis "Cumulative % Bad".
plt.title('Gini')
# We name the graph "Gini".
# Out:
# Text(0.5, 1.0, 'Gini')

# %%
Gini = AUROC * 2 - 1
# Here we calculate Gini from AUROC.
Gini
# Out:
# 0.39501520586370864

# %%
# Plot KS
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Bad'], color = 'r')
# We plot the predicted (estimated) probabilities along the x-axis and the cumulative percentage 'bad' along the y-axis,
# colored in red.
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Good'], color = 'b')
# We plot the predicted (estimated) probabilities along the x-axis and the cumulative percentage 'good' along the y-axis,
# colored in red.
plt.xlabel('Estimated Probability for being Good')
# We name the x-axis "Estimated Probability for being Good".
plt.ylabel('Cumulative %')
# We name the y-axis "Cumulative %".
plt.title('Kolmogorov-Smirnov')
# We name the graph "Kolmogorov-Smirnov".
# Out:
# Text(0.5, 1.0, 'Kolmogorov-Smirnov')

# %%
KS = max(df_actual_predicted_probs['Cumulative Perc Bad'] - df_actual_predicted_probs['Cumulative Perc Good'])
# We calculate KS from the data. It is the maximum of the difference between the cumulative percentage of 'bad'
# and the cumulative percentage of 'good'.
KS
# Out:
# 0.28642466479937373

# %% [markdown]
# # Applying the PD Model

# %% [markdown]
# ### Calculating PD of individual accounts

# %%
pd.options.display.max_columns = None
# Sets the pandas dataframe options to display all columns/ rows.

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 427211        1        0        0        0        0        0        0
# 206088        0        0        1        0        0        0        0
# 136020        1        0        0        0        0        0        0
# 412305        0        0        0        1        0        0        0
# 36159         0        0        1        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 427211                                   0                   0
# 206088                                   0                   0
# 136020                                   0                   0
# 412305                                   1                   0
# 36159                                    0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 427211                        1                                0
# 206088                        1                                0
# 136020                        1                                0
# 412305                        0                                0
# 36159                         1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 427211                 0              0                             0
# 206088                 0              0                             0
# 136020                 0              0                             0
# 412305                 0              0                             0
# 36159                  0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 427211              0                       0                          0
# 206088              0                       1                          0
# 136020              0                       0                          0
# 412305              0                       0                          0
# 36159               1                       0                          0
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 427211                          0                    0                 0
# 206088                          0                    0                 0
# 136020                          0                    1                 0
# 412305                          1                    0                 0
# 36159                           0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 427211              0                 0                             1
# 206088              0                 0                             0
# 136020              0                 0                             0
# 412305              0                 0                             0
# 36159               0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 427211                             0                                 0
# 206088                             0                                 1
# 136020                             0                                 0
# 412305                             0                                 0
# 36159                              0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 427211                                    1                             0
# 206088                                    0                             0
# 136020                                    0                             1
# 412305                                    1                             0
# 36159                                     0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 427211                                             0                    0
# 206088                                             0                    0
# 136020                                             0                    0
# 412305                                             0                    0
# 36159                                              1                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 427211                           1                           0
# 206088                           1                           0
# 136020                           1                           0
# 412305                           1                           0
# 36159                            0                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 427211                                    0                      1
# 206088                                    0                      1
# 136020                                    0                      1
# 412305                                    0                      1
# 36159                                     0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 427211                      0        1        0             0             0
# 206088                      0        1        0             0             0
# 136020                      0        1        0             0             0
# 412305                      0        1        0             0             0
# 36159                       0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 427211               1               0               0              0
# 206088               0               1               0              0
# 136020               0               0               0              1
# 412305               0               0               1              0
# 36159                0               1               0              0
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 427211                       0                         0
# 206088                       0                         0
# 136020                       0                         0
# 412305                       0                         0
# 36159                        0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 427211                         0                         1
# 206088                         0                         0
# 136020                         0                         0
# 412305                         0                         1
# 36159                          0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 427211                         0                         0
# 206088                         0                         1
# 136020                         0                         1
# 412305                         0                         0
# 36159                          0                         0
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 427211                         0                       0                1
# 206088                         0                       0                0
# 136020                         0                       0                1
# 412305                         0                       0                0
# 36159                          0                       1                0
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 427211                      0                      0                      0
# 206088                      0                      1                      0
# 136020                      0                      0                      0
# 412305                      0                      0                      1
# 36159                       0                      1                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 427211                 0                                 0
# 206088                 0                                 0
# 136020                 0                                 0
# 412305                 0                                 0
# 36159                  0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:165-247  \
# 427211                                    0
# 206088                                    1
# 136020                                    0
# 412305                                    1
# 36159                                     1
#
#         mths_since_earliest_cr_line:248-270  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 427211                                    0                                 1
# 206088                                    0                                 0
# 136020                                    1                                 0
# 412305                                    0                                 0
# 36159                                     0                                 0
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 427211                 0                   1                   0
# 206088                 0                   1                   0
# 136020                 0                   1                   0
# 412305                 0                   0                   1
# 36159                  0                   1                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 427211                  0                 1                   0
# 206088                  0                 1                   0
# 136020                  0                 1                   0
# 412305                  0                 1                   0
# 36159                   0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 427211                0                   0                   0
# 206088                0                   0                   0
# 136020                0                   0                   0
# 412305                0                   0                   0
# 36159                 0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 427211                   0                   0                   0
# 206088                   0                   0                   0
# 136020                   0                   0                   0
# 412305                   1                   0                   0
# 36159                    0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 427211                   1                   0                    0
# 206088                   0                   0                    0
# 136020                   0                   1                    0
# 412305                   0                   0                    0
# 36159                    0                   0                    1
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 427211                     0                     0                 0
# 206088                     1                     0                 0
# 136020                     0                     0                 0
# 412305                     0                     0                 0
# 36159                      0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 427211          0            0            0             0              0
# 206088          0            0            1             0              0
# 136020          0            0            0             0              1
# 412305          0            0            0             0              1
# 36159           0            0            0             0              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 427211              0              0              1            0        0
# 206088              0              0              0            0        0
# 136020              0              0              0            0        0
# 412305              0              0              0            0        0
# 36159               0              0              0            1        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 427211                               1                           0
# 206088                               0                           0
# 136020                               0                           0
# 412305                               0                           0
# 36159                                1                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 427211                           0                            0
# 206088                           0                            0
# 136020                           0                            0
# 412305                           0                            0
# 36159                            0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:81-86
# 427211                             0
# 206088                             0
# 136020                             0
# 412305                             0
# 36159                              0

# %%
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -1.286571
# 1                               grade:A      1.155580
# 2                               grade:B      0.912933
# 3                               grade:C      0.716380
# 4                               grade:D      0.525330
# 5                               grade:E      0.342265
# 6                               grade:F      0.152201
# 7                    home_ownership:OWN      0.093714
# 8               home_ownership:MORTGAGE      0.106218
# 9                      addr_state:NM_VA      0.036098
# 10                        addr_state:NY      0.057793
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12                        addr_state:CA      0.063949
# 13               addr_state:UT_KY_AZ_NJ      0.078983
# 14            addr_state:AR_MI_PA_OH_MN      0.136948
# 15            addr_state:RI_MA_DE_SD_IN      0.101655
# 16                  addr_state:GA_WA_OR      0.185746
# 17                     addr_state:WI_MT      0.240456
# 18                        addr_state:TX      0.222863
# 19                     addr_state:IL_CT      0.262768
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22     verification_status:Not Verified      0.084434
# 23  verification_status:Source Verified     -0.010560
# 24                  purpose:credit_card      0.300415
# 25           purpose:debt_consolidation      0.197168
# 26           purpose:oth__med__vacation      0.213265
# 27  purpose:major_purch__car__home_impr      0.265546
# 28                initial_list_status:w      0.054820
# 29                              term:36      0.078657
# 30                         emp_length:1      0.099199
# 31                       emp_length:2-4      0.126174
# 32                       emp_length:5-6      0.091429
# 33                       emp_length:7-9      0.061589
# 34                        emp_length:10      0.125336
# 35               mths_since_issue_d:<38      1.091989
# 36             mths_since_issue_d:38-39      0.890632
# 37             mths_since_issue_d:40-41      0.788919
# 38             mths_since_issue_d:42-48      0.587156
# 39             mths_since_issue_d:49-52      0.425053
# 40             mths_since_issue_d:53-64      0.178658
# 41             mths_since_issue_d:65-84     -0.060625
# 42                      int_rate:<9.548      0.867403
# 43                int_rate:9.548-12.025      0.540435
# 44                int_rate:12.025-15.74      0.291230
# 45                int_rate:15.74-20.281      0.103116
# 46  mths_since_earliest_cr_line:141-164      0.056439
# 47  mths_since_earliest_cr_line:165-247      0.038175
# 48  mths_since_earliest_cr_line:248-270      0.080625
# 49  mths_since_earliest_cr_line:271-352      0.122839
# 50     mths_since_earliest_cr_line:>352      0.131429
# 51                     inq_last_6mths:0      0.694464
# 52                   inq_last_6mths:1-2      0.547345
# 53                   inq_last_6mths:3-6      0.336631
# 54                   acc_now_delinq:>=1      0.235451
# 55                   annual_inc:20K-30K     -0.068940
# 56                   annual_inc:30K-40K     -0.005534
# 57                   annual_inc:40K-50K      0.089310
# 58                   annual_inc:50K-60K      0.156335
# 59                   annual_inc:60K-70K      0.231736
# 60                   annual_inc:70K-80K      0.306246
# 61                   annual_inc:80K-90K      0.380309
# 62                  annual_inc:90K-100K      0.400762
# 63                 annual_inc:100K-120K      0.479392
# 64                 annual_inc:120K-140K      0.577041
# 65                     annual_inc:>140K      0.505299
# 66                            dti:<=1.4      0.252541
# 67                          dti:1.4-3.5      0.371493
# 68                          dti:3.5-7.7      0.389216
# 69                         dti:7.7-10.5      0.324627
# 70                        dti:10.5-16.1      0.245253
# 71                        dti:16.1-20.3      0.143907
# 72                        dti:20.3-21.7      0.132742
# 73                        dti:21.7-22.4      0.097492
# 74                          dti:22.4-35      0.054606
# 75       mths_since_last_delinq:Missing      0.167526
# 76          mths_since_last_delinq:4-30      0.192266
# 77         mths_since_last_delinq:31-56      0.239033
# 78          mths_since_last_delinq:>=57      0.191772
# 79       mths_since_last_record:Missing      0.102726
# 80          mths_since_last_record:3-20      0.212815
# 81         mths_since_last_record:21-31      0.135718
# 82         mths_since_last_record:32-80      0.286681
# 83         mths_since_last_record:81-86     -0.049878

# %%
y_hat_test_proba
# Out:
# array([0.97054287, 0.90768621, 0.96251831, ..., 0.92277708, 0.91601681,
#        0.91037161])

# %% [markdown]
# ### Creating a Scorecard

# %%
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -1.286571
# 1                               grade:A      1.155580
# 2                               grade:B      0.912933
# 3                               grade:C      0.716380
# 4                               grade:D      0.525330
# 5                               grade:E      0.342265
# 6                               grade:F      0.152201
# 7                    home_ownership:OWN      0.093714
# 8               home_ownership:MORTGAGE      0.106218
# 9                      addr_state:NM_VA      0.036098
# 10                        addr_state:NY      0.057793
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12                        addr_state:CA      0.063949
# 13               addr_state:UT_KY_AZ_NJ      0.078983
# 14            addr_state:AR_MI_PA_OH_MN      0.136948
# 15            addr_state:RI_MA_DE_SD_IN      0.101655
# 16                  addr_state:GA_WA_OR      0.185746
# 17                     addr_state:WI_MT      0.240456
# 18                        addr_state:TX      0.222863
# 19                     addr_state:IL_CT      0.262768
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22     verification_status:Not Verified      0.084434
# 23  verification_status:Source Verified     -0.010560
# 24                  purpose:credit_card      0.300415
# 25           purpose:debt_consolidation      0.197168
# 26           purpose:oth__med__vacation      0.213265
# 27  purpose:major_purch__car__home_impr      0.265546
# 28                initial_list_status:w      0.054820
# 29                              term:36      0.078657
# 30                         emp_length:1      0.099199
# 31                       emp_length:2-4      0.126174
# 32                       emp_length:5-6      0.091429
# 33                       emp_length:7-9      0.061589
# 34                        emp_length:10      0.125336
# 35               mths_since_issue_d:<38      1.091989
# 36             mths_since_issue_d:38-39      0.890632
# 37             mths_since_issue_d:40-41      0.788919
# 38             mths_since_issue_d:42-48      0.587156
# 39             mths_since_issue_d:49-52      0.425053
# 40             mths_since_issue_d:53-64      0.178658
# 41             mths_since_issue_d:65-84     -0.060625
# 42                      int_rate:<9.548      0.867403
# 43                int_rate:9.548-12.025      0.540435
# 44                int_rate:12.025-15.74      0.291230
# 45                int_rate:15.74-20.281      0.103116
# 46  mths_since_earliest_cr_line:141-164      0.056439
# 47  mths_since_earliest_cr_line:165-247      0.038175
# 48  mths_since_earliest_cr_line:248-270      0.080625
# 49  mths_since_earliest_cr_line:271-352      0.122839
# 50     mths_since_earliest_cr_line:>352      0.131429
# 51                     inq_last_6mths:0      0.694464
# 52                   inq_last_6mths:1-2      0.547345
# 53                   inq_last_6mths:3-6      0.336631
# 54                   acc_now_delinq:>=1      0.235451
# 55                   annual_inc:20K-30K     -0.068940
# 56                   annual_inc:30K-40K     -0.005534
# 57                   annual_inc:40K-50K      0.089310
# 58                   annual_inc:50K-60K      0.156335
# 59                   annual_inc:60K-70K      0.231736
# 60                   annual_inc:70K-80K      0.306246
# 61                   annual_inc:80K-90K      0.380309
# 62                  annual_inc:90K-100K      0.400762
# 63                 annual_inc:100K-120K      0.479392
# 64                 annual_inc:120K-140K      0.577041
# 65                     annual_inc:>140K      0.505299
# 66                            dti:<=1.4      0.252541
# 67                          dti:1.4-3.5      0.371493
# 68                          dti:3.5-7.7      0.389216
# 69                         dti:7.7-10.5      0.324627
# 70                        dti:10.5-16.1      0.245253
# 71                        dti:16.1-20.3      0.143907
# 72                        dti:20.3-21.7      0.132742
# 73                        dti:21.7-22.4      0.097492
# 74                          dti:22.4-35      0.054606
# 75       mths_since_last_delinq:Missing      0.167526
# 76          mths_since_last_delinq:4-30      0.192266
# 77         mths_since_last_delinq:31-56      0.239033
# 78          mths_since_last_delinq:>=57      0.191772
# 79       mths_since_last_record:Missing      0.102726
# 80          mths_since_last_record:3-20      0.212815
# 81         mths_since_last_record:21-31      0.135718
# 82         mths_since_last_record:32-80      0.286681
# 83         mths_since_last_record:81-86     -0.049878

# %%
ref_categories
# Out:
# ['grade:G',
#  'home_ownership:RENT_OTHER_NONE_ANY',
#  'addr_state:ND_NE_IA_NV_FL_HI_AL',
#  'verification_status:Verified',
#  'purpose:educ__sm_b__wedd__ren_en__mov__house',
#  'initial_list_status:f',
#  'term:60',
#  'emp_length:0',
#  'mths_since_issue_d:>84',
#  'int_rate:>20.281',
#  'mths_since_earliest_cr_line:<140',
#  'inq_last_6mths:>6',
#  'acc_now_delinq:0',
#  'annual_inc:<20K',
#  'dti:>35',
#  'mths_since_last_delinq:0-3',
#  'mths_since_last_record:0-2']

# %%
df_ref_categories = pd.DataFrame(ref_categories, columns = ['Feature name'])
# We create a new dataframe with one column. Its values are the values from the 'reference_categories' list.
# We name it 'Feature name'.
df_ref_categories['Coefficients'] = 0
# We create a second column, called 'Coefficients', which contains only 0 values.
df_ref_categories['p_values'] = np.nan
# We create a third column, called 'p_values', with contains only NaN values.
df_ref_categories
# Out:
#                                     Feature name  Coefficients  p_values
# 0                                        grade:G             0       NaN
# 1             home_ownership:RENT_OTHER_NONE_ANY             0       NaN
# 2                addr_state:ND_NE_IA_NV_FL_HI_AL             0       NaN
# 3                   verification_status:Verified             0       NaN
# 4   purpose:educ__sm_b__wedd__ren_en__mov__house             0       NaN
# 5                          initial_list_status:f             0       NaN
# 6                                        term:60             0       NaN
# 7                                   emp_length:0             0       NaN
# 8                         mths_since_issue_d:>84             0       NaN
# 9                               int_rate:>20.281             0       NaN
# 10              mths_since_earliest_cr_line:<140             0       NaN
# 11                             inq_last_6mths:>6             0       NaN
# 12                              acc_now_delinq:0             0       NaN
# 13                               annual_inc:<20K             0       NaN
# 14                                       dti:>35             0       NaN
# 15                    mths_since_last_delinq:0-3             0       NaN
# 16                    mths_since_last_record:0-2             0       NaN

# %%
df_scorecard = pd.concat([summary_table, df_ref_categories])
# Concatenates two dataframes.
df_scorecard = df_scorecard.reset_index()
# We reset the index of a dataframe.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286571
# 1        1                                       grade:A      1.155580
# 2        2                                       grade:B      0.912933
# 3        3                                       grade:C      0.716380
# 4        4                                       grade:D      0.525330
# 5        5                                       grade:E      0.342265
# 6        6                                       grade:F      0.152201
# 7        7                            home_ownership:OWN      0.093714
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036098
# 10      10                                 addr_state:NY      0.057793
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12      12                                 addr_state:CA      0.063949
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078983
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136948
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101655
# 16      16                           addr_state:GA_WA_OR      0.185746
# 17      17                              addr_state:WI_MT      0.240456
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262768
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22      22              verification_status:Not Verified      0.084434
# 23      23           verification_status:Source Verified     -0.010560
# 24      24                           purpose:credit_card      0.300415
# 25      25                    purpose:debt_consolidation      0.197168
# 26      26                    purpose:oth__med__vacation      0.213265
# 27      27           purpose:major_purch__car__home_impr      0.265546
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078657
# 30      30                                  emp_length:1      0.099199
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125336
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425053
# 40      40                      mths_since_issue_d:53-64      0.178658
# 41      41                      mths_since_issue_d:65-84     -0.060625
# 42      42                               int_rate:<9.548      0.867403
# 43      43                         int_rate:9.548-12.025      0.540435
# 44      44                         int_rate:12.025-15.74      0.291230
# 45      45                         int_rate:15.74-20.281      0.103116
# 46      46           mths_since_earliest_cr_line:141-164      0.056439
# 47      47           mths_since_earliest_cr_line:165-247      0.038175
# 48      48           mths_since_earliest_cr_line:248-270      0.080625
# 49      49           mths_since_earliest_cr_line:271-352      0.122839
# 50      50              mths_since_earliest_cr_line:>352      0.131429
# 51      51                              inq_last_6mths:0      0.694464
# 52      52                            inq_last_6mths:1-2      0.547345
# 53      53                            inq_last_6mths:3-6      0.336631
# 54      54                            acc_now_delinq:>=1      0.235451
# 55      55                            annual_inc:20K-30K     -0.068940
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306246
# 61      61                            annual_inc:80K-90K      0.380309
# 62      62                           annual_inc:90K-100K      0.400762
# 63      63                          annual_inc:100K-120K      0.479392
# 64      64                          annual_inc:120K-140K      0.577041
# 65      65                              annual_inc:>140K      0.505299
# 66      66                                     dti:<=1.4      0.252541
# 67      67                                   dti:1.4-3.5      0.371493
# 68      68                                   dti:3.5-7.7      0.389216
# 69      69                                  dti:7.7-10.5      0.324627
# 70      70                                 dti:10.5-16.1      0.245253
# 71      71                                 dti:16.1-20.3      0.143907
# 72      72                                 dti:20.3-21.7      0.132742
# 73      73                                 dti:21.7-22.4      0.097492
# 74      74                                   dti:22.4-35      0.054606
# 75      75                mths_since_last_delinq:Missing      0.167526
# 76      76                   mths_since_last_delinq:4-30      0.192266
# 77      77                  mths_since_last_delinq:31-56      0.239033
# 78      78                   mths_since_last_delinq:>=57      0.191772
# 79      79                mths_since_last_record:Missing      0.102726
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135718
# 82      82                  mths_since_last_record:32-80      0.286681
# 83      83                  mths_since_last_record:81-86     -0.049878
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#      p_values
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 51        NaN
# 52        NaN
# 53        NaN
# 54        NaN
# 55        NaN
# 56        NaN
# 57        NaN
# 58        NaN
# 59        NaN
# 60        NaN
# 61        NaN
# 62        NaN
# 63        NaN
# 64        NaN
# 65        NaN
# 66        NaN
# 67        NaN
# 68        NaN
# 69        NaN
# 70        NaN
# 71        NaN
# 72        NaN
# 73        NaN
# 74        NaN
# 75        NaN
# 76        NaN
# 77        NaN
# 78        NaN
# 79        NaN
# 80        NaN
# 81        NaN
# 82        NaN
# 83        NaN
# 84        NaN
# 85        NaN
# 86        NaN
# 87        NaN
# 88        NaN
# 89        NaN
# 90        NaN
# 91        NaN
# 92        NaN
# 93        NaN
# 94        NaN
# 95        NaN
# 96        NaN
# 97        NaN
# 98        NaN
# 99        NaN
# 100       NaN

# %%
df_scorecard['Original feature name'] = df_scorecard['Feature name'].str.split(':').str[0]
# We create a new column, called 'Original feature name', which contains the value of the 'Feature name' column,
# up to the column symbol.

# %%
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286571
# 1        1                                       grade:A      1.155580
# 2        2                                       grade:B      0.912933
# 3        3                                       grade:C      0.716380
# 4        4                                       grade:D      0.525330
# 5        5                                       grade:E      0.342265
# 6        6                                       grade:F      0.152201
# 7        7                            home_ownership:OWN      0.093714
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036098
# 10      10                                 addr_state:NY      0.057793
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12      12                                 addr_state:CA      0.063949
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078983
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136948
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101655
# 16      16                           addr_state:GA_WA_OR      0.185746
# 17      17                              addr_state:WI_MT      0.240456
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262768
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22      22              verification_status:Not Verified      0.084434
# 23      23           verification_status:Source Verified     -0.010560
# 24      24                           purpose:credit_card      0.300415
# 25      25                    purpose:debt_consolidation      0.197168
# 26      26                    purpose:oth__med__vacation      0.213265
# 27      27           purpose:major_purch__car__home_impr      0.265546
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078657
# 30      30                                  emp_length:1      0.099199
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125336
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425053
# 40      40                      mths_since_issue_d:53-64      0.178658
# 41      41                      mths_since_issue_d:65-84     -0.060625
# 42      42                               int_rate:<9.548      0.867403
# 43      43                         int_rate:9.548-12.025      0.540435
# 44      44                         int_rate:12.025-15.74      0.291230
# 45      45                         int_rate:15.74-20.281      0.103116
# 46      46           mths_since_earliest_cr_line:141-164      0.056439
# 47      47           mths_since_earliest_cr_line:165-247      0.038175
# 48      48           mths_since_earliest_cr_line:248-270      0.080625
# 49      49           mths_since_earliest_cr_line:271-352      0.122839
# 50      50              mths_since_earliest_cr_line:>352      0.131429
# 51      51                              inq_last_6mths:0      0.694464
# 52      52                            inq_last_6mths:1-2      0.547345
# 53      53                            inq_last_6mths:3-6      0.336631
# 54      54                            acc_now_delinq:>=1      0.235451
# 55      55                            annual_inc:20K-30K     -0.068940
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306246
# 61      61                            annual_inc:80K-90K      0.380309
# 62      62                           annual_inc:90K-100K      0.400762
# 63      63                          annual_inc:100K-120K      0.479392
# 64      64                          annual_inc:120K-140K      0.577041
# 65      65                              annual_inc:>140K      0.505299
# 66      66                                     dti:<=1.4      0.252541
# 67      67                                   dti:1.4-3.5      0.371493
# 68      68                                   dti:3.5-7.7      0.389216
# 69      69                                  dti:7.7-10.5      0.324627
# 70      70                                 dti:10.5-16.1      0.245253
# 71      71                                 dti:16.1-20.3      0.143907
# 72      72                                 dti:20.3-21.7      0.132742
# 73      73                                 dti:21.7-22.4      0.097492
# 74      74                                   dti:22.4-35      0.054606
# 75      75                mths_since_last_delinq:Missing      0.167526
# 76      76                   mths_since_last_delinq:4-30      0.192266
# 77      77                  mths_since_last_delinq:31-56      0.239033
# 78      78                   mths_since_last_delinq:>=57      0.191772
# 79      79                mths_since_last_record:Missing      0.102726
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135718
# 82      82                  mths_since_last_record:32-80      0.286681
# 83      83                  mths_since_last_record:81-86     -0.049878
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name
# 0         NaN                    Intercept
# 1         NaN                        grade
# 2         NaN                        grade
# 3         NaN                        grade
# 4         NaN                        grade
# 5         NaN                        grade
# 6         NaN                        grade
# 7         NaN               home_ownership
# 8         NaN               home_ownership
# 9         NaN                   addr_state
# 10        NaN                   addr_state
# 11        NaN                   addr_state
# 12        NaN                   addr_state
# 13        NaN                   addr_state
# 14        NaN                   addr_state
# 15        NaN                   addr_state
# 16        NaN                   addr_state
# 17        NaN                   addr_state
# 18        NaN                   addr_state
# 19        NaN                   addr_state
# 20        NaN                   addr_state
# 21        NaN                   addr_state
# 22        NaN          verification_status
# 23        NaN          verification_status
# 24        NaN                      purpose
# 25        NaN                      purpose
# 26        NaN                      purpose
# 27        NaN                      purpose
# 28        NaN          initial_list_status
# 29        NaN                         term
# 30        NaN                   emp_length
# 31        NaN                   emp_length
# 32        NaN                   emp_length
# 33        NaN                   emp_length
# 34        NaN                   emp_length
# 35        NaN           mths_since_issue_d
# 36        NaN           mths_since_issue_d
# 37        NaN           mths_since_issue_d
# 38        NaN           mths_since_issue_d
# 39        NaN           mths_since_issue_d
# 40        NaN           mths_since_issue_d
# 41        NaN           mths_since_issue_d
# 42        NaN                     int_rate
# 43        NaN                     int_rate
# 44        NaN                     int_rate
# 45        NaN                     int_rate
# 46        NaN  mths_since_earliest_cr_line
# 47        NaN  mths_since_earliest_cr_line
# 48        NaN  mths_since_earliest_cr_line
# 49        NaN  mths_since_earliest_cr_line
# 50        NaN  mths_since_earliest_cr_line
# 51        NaN               inq_last_6mths
# 52        NaN               inq_last_6mths
# 53        NaN               inq_last_6mths
# 54        NaN               acc_now_delinq
# 55        NaN                   annual_inc
# 56        NaN                   annual_inc
# 57        NaN                   annual_inc
# 58        NaN                   annual_inc
# 59        NaN                   annual_inc
# 60        NaN                   annual_inc
# 61        NaN                   annual_inc
# 62        NaN                   annual_inc
# 63        NaN                   annual_inc
# 64        NaN                   annual_inc
# 65        NaN                   annual_inc
# 66        NaN                          dti
# 67        NaN                          dti
# 68        NaN                          dti
# 69        NaN                          dti
# 70        NaN                          dti
# 71        NaN                          dti
# 72        NaN                          dti
# 73        NaN                          dti
# 74        NaN                          dti
# 75        NaN       mths_since_last_delinq
# 76        NaN       mths_since_last_delinq
# 77        NaN       mths_since_last_delinq
# 78        NaN       mths_since_last_delinq
# 79        NaN       mths_since_last_record
# 80        NaN       mths_since_last_record
# 81        NaN       mths_since_last_record
# 82        NaN       mths_since_last_record
# 83        NaN       mths_since_last_record
# 84        NaN                        grade
# 85        NaN               home_ownership
# 86        NaN                   addr_state
# 87        NaN          verification_status
# 88        NaN                      purpose
# 89        NaN          initial_list_status
# 90        NaN                         term
# 91        NaN                   emp_length
# 92        NaN           mths_since_issue_d
# 93        NaN                     int_rate
# 94        NaN  mths_since_earliest_cr_line
# 95        NaN               inq_last_6mths
# 96        NaN               acc_now_delinq
# 97        NaN                   annual_inc
# 98        NaN                          dti
# 99        NaN       mths_since_last_delinq
# 100       NaN       mths_since_last_record

# %%
min_score = 300
max_score = 850

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].min()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Out:
# Original feature name
# Intercept                     -1.286571
# acc_now_delinq                 0.000000
# addr_state                     0.000000
# annual_inc                    -0.068940
# dti                            0.000000
# emp_length                     0.000000
# grade                          0.000000
# home_ownership                 0.000000
# initial_list_status            0.000000
# inq_last_6mths                 0.000000
# int_rate                       0.000000
# mths_since_earliest_cr_line    0.000000
# mths_since_issue_d            -0.060625
# mths_since_last_delinq         0.000000
# mths_since_last_record        -0.049878
# purpose                        0.000000
# term                           0.000000
# verification_status           -0.010560
# Name: Coefficients, dtype: float64

# %%
min_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].min().sum()
# Up to the 'min()' method everything is the same as in te line above.
# Then, we aggregate further and sum all the minimum values.
min_sum_coef
# Out:
# -1.4765743553946118

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].max()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Out:
# Original feature name
# Intercept                     -1.286571
# acc_now_delinq                 0.235451
# addr_state                     0.524195
# annual_inc                     0.577041
# dti                            0.389216
# emp_length                     0.126174
# grade                          1.155580
# home_ownership                 0.106218
# initial_list_status            0.054820
# inq_last_6mths                 0.694464
# int_rate                       0.867403
# mths_since_earliest_cr_line    0.131429
# mths_since_issue_d             1.091989
# mths_since_last_delinq         0.239033
# mths_since_last_record         0.286681
# purpose                        0.300415
# term                           0.078657
# verification_status            0.084434
# Name: Coefficients, dtype: float64

# %%
max_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].max().sum()
# Up to the 'min()' method everything is the same as in te line above.
# Then, we aggregate further and sum all the maximum values.
max_sum_coef
# Out:
# 5.6566286345047745

# %%
df_scorecard['Score - Calculation'] = df_scorecard['Coefficients'] * (max_score - min_score) / (max_sum_coef - min_sum_coef)
# We multiply the value of the 'Coefficients' column by the ration of the differences between
# maximum score and minimum score and maximum sum of coefficients and minimum sum of cefficients.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286571
# 1        1                                       grade:A      1.155580
# 2        2                                       grade:B      0.912933
# 3        3                                       grade:C      0.716380
# 4        4                                       grade:D      0.525330
# 5        5                                       grade:E      0.342265
# 6        6                                       grade:F      0.152201
# 7        7                            home_ownership:OWN      0.093714
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036098
# 10      10                                 addr_state:NY      0.057793
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12      12                                 addr_state:CA      0.063949
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078983
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136948
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101655
# 16      16                           addr_state:GA_WA_OR      0.185746
# 17      17                              addr_state:WI_MT      0.240456
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262768
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22      22              verification_status:Not Verified      0.084434
# 23      23           verification_status:Source Verified     -0.010560
# 24      24                           purpose:credit_card      0.300415
# 25      25                    purpose:debt_consolidation      0.197168
# 26      26                    purpose:oth__med__vacation      0.213265
# 27      27           purpose:major_purch__car__home_impr      0.265546
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078657
# 30      30                                  emp_length:1      0.099199
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125336
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425053
# 40      40                      mths_since_issue_d:53-64      0.178658
# 41      41                      mths_since_issue_d:65-84     -0.060625
# 42      42                               int_rate:<9.548      0.867403
# 43      43                         int_rate:9.548-12.025      0.540435
# 44      44                         int_rate:12.025-15.74      0.291230
# 45      45                         int_rate:15.74-20.281      0.103116
# 46      46           mths_since_earliest_cr_line:141-164      0.056439
# 47      47           mths_since_earliest_cr_line:165-247      0.038175
# 48      48           mths_since_earliest_cr_line:248-270      0.080625
# 49      49           mths_since_earliest_cr_line:271-352      0.122839
# 50      50              mths_since_earliest_cr_line:>352      0.131429
# 51      51                              inq_last_6mths:0      0.694464
# 52      52                            inq_last_6mths:1-2      0.547345
# 53      53                            inq_last_6mths:3-6      0.336631
# 54      54                            acc_now_delinq:>=1      0.235451
# 55      55                            annual_inc:20K-30K     -0.068940
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306246
# 61      61                            annual_inc:80K-90K      0.380309
# 62      62                           annual_inc:90K-100K      0.400762
# 63      63                          annual_inc:100K-120K      0.479392
# 64      64                          annual_inc:120K-140K      0.577041
# 65      65                              annual_inc:>140K      0.505299
# 66      66                                     dti:<=1.4      0.252541
# 67      67                                   dti:1.4-3.5      0.371493
# 68      68                                   dti:3.5-7.7      0.389216
# 69      69                                  dti:7.7-10.5      0.324627
# 70      70                                 dti:10.5-16.1      0.245253
# 71      71                                 dti:16.1-20.3      0.143907
# 72      72                                 dti:20.3-21.7      0.132742
# 73      73                                 dti:21.7-22.4      0.097492
# 74      74                                   dti:22.4-35      0.054606
# 75      75                mths_since_last_delinq:Missing      0.167526
# 76      76                   mths_since_last_delinq:4-30      0.192266
# 77      77                  mths_since_last_delinq:31-56      0.239033
# 78      78                   mths_since_last_delinq:>=57      0.191772
# 79      79                mths_since_last_record:Missing      0.102726
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135718
# 82      82                  mths_since_last_record:32-80      0.286681
# 83      83                  mths_since_last_record:81-86     -0.049878
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation
# 0         NaN                    Intercept           -99.200017
# 1         NaN                        grade            89.100094
# 2         NaN                        grade            70.390995
# 3         NaN                        grade            55.235911
# 4         NaN                        grade            40.505119
# 5         NaN                        grade            26.390105
# 6         NaN                        grade            11.735332
# 7         NaN               home_ownership             7.225742
# 8         NaN               home_ownership             8.189834
# 9         NaN                   addr_state             2.783329
# 10        NaN                   addr_state             4.456060
# 11        NaN                   addr_state             4.613140
# 12        NaN                   addr_state             4.930748
# 13        NaN                   addr_state             6.089960
# 14        NaN                   addr_state            10.559279
# 15        NaN                   addr_state             7.838058
# 16        NaN                   addr_state            14.321777
# 17        NaN                   addr_state            18.540180
# 18        NaN                   addr_state            17.183651
# 19        NaN                   addr_state            20.260558
# 20        NaN                   addr_state            24.745089
# 21        NaN                   addr_state            40.417662
# 22        NaN          verification_status             6.510205
# 23        NaN          verification_status            -0.814248
# 24        NaN                      purpose            23.163234
# 25        NaN                      purpose            15.202517
# 26        NaN                      purpose            16.443648
# 27        NaN                      purpose            20.474683
# 28        NaN          initial_list_status             4.226872
# 29        NaN                         term             6.064820
# 30        NaN                   emp_length             7.648681
# 31        NaN                   emp_length             9.728529
# 32        NaN                   emp_length             7.049532
# 33        NaN                   emp_length             4.748764
# 34        NaN                   emp_length             9.663909
# 35        NaN           mths_since_issue_d            84.196953
# 36        NaN           mths_since_issue_d            68.671486
# 37        NaN           mths_since_issue_d            60.828946
# 38        NaN           mths_since_issue_d            45.272175
# 39        NaN           mths_since_issue_d            32.773341
# 40        NaN           mths_since_issue_d            13.775279
# 41        NaN           mths_since_issue_d            -4.674454
# 42        NaN                     int_rate            66.880402
# 43        NaN                     int_rate            41.669830
# 44        NaN                     int_rate            22.455025
# 45        NaN                     int_rate             7.950688
# 46        NaN  mths_since_earliest_cr_line             4.351721
# 47        NaN  mths_since_earliest_cr_line             2.943427
# 48        NaN  mths_since_earliest_cr_line             6.216501
# 49        NaN  mths_since_earliest_cr_line             9.471440
# 50        NaN  mths_since_earliest_cr_line            10.133767
# 51        NaN               inq_last_6mths            53.546082
# 52        NaN               inq_last_6mths            42.202630
# 53        NaN               inq_last_6mths            25.955679
# 54        NaN               acc_now_delinq            18.154267
# 55        NaN                   annual_inc            -5.315545
# 56        NaN                   annual_inc            -0.426663
# 57        NaN                   annual_inc             6.886185
# 58        NaN                   annual_inc            12.054096
# 59        NaN                   annual_inc            17.867807
# 60        NaN                   annual_inc            23.612852
# 61        NaN                   annual_inc            29.323448
# 62        NaN                   annual_inc            30.900409
# 63        NaN                   annual_inc            36.963119
# 64        NaN                   annual_inc            44.492291
# 65        NaN                   annual_inc            38.960709
# 66        NaN                          dti            19.471955
# 67        NaN                          dti            28.643708
# 68        NaN                          dti            30.010158
# 69        NaN                          dti            25.030146
# 70        NaN                          dti            18.910019
# 71        NaN                          dti            11.095855
# 72        NaN                          dti            10.234942
# 73        NaN                          dti             7.517056
# 74        NaN                          dti             4.210330
# 75        NaN       mths_since_last_delinq            12.916959
# 76        NaN       mths_since_last_delinq            14.824528
# 77        NaN       mths_since_last_delinq            18.430454
# 78        NaN       mths_since_last_delinq            14.786437
# 79        NaN       mths_since_last_record             7.920576
# 80        NaN       mths_since_last_record            16.408937
# 81        NaN       mths_since_last_record            10.464400
# 82        NaN       mths_since_last_record            22.104291
# 83        NaN       mths_since_last_record            -3.845839
# 84        NaN                        grade             0.000000
# 85        NaN               home_ownership             0.000000
# 86        NaN                   addr_state             0.000000
# 87        NaN          verification_status             0.000000
# 88        NaN                      purpose             0.000000
# 89        NaN          initial_list_status             0.000000
# 90        NaN                         term             0.000000
# 91        NaN                   emp_length             0.000000
# 92        NaN           mths_since_issue_d             0.000000
# 93        NaN                     int_rate             0.000000
# 94        NaN  mths_since_earliest_cr_line             0.000000
# 95        NaN               inq_last_6mths             0.000000
# 96        NaN               acc_now_delinq             0.000000
# 97        NaN                   annual_inc             0.000000
# 98        NaN                          dti             0.000000
# 99        NaN       mths_since_last_delinq             0.000000
# 100       NaN       mths_since_last_record             0.000000

# %%
df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
# We divide the difference of the value of the 'Coefficients' column and the minimum sum of coefficients by
# the difference of the maximum sum of coefficients and the minimum sum of coefficients.
# Then, we multiply that by the difference between the maximum score and the minimum score.
# Then, we add minimum score. 
df_scorecard
# Out:
# C:\Users\om\AppData\Local\Temp\ipykernel_23292\1410049194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286571
# 1        1                                       grade:A      1.155580
# 2        2                                       grade:B      0.912933
# 3        3                                       grade:C      0.716380
# 4        4                                       grade:D      0.525330
# 5        5                                       grade:E      0.342265
# 6        6                                       grade:F      0.152201
# 7        7                            home_ownership:OWN      0.093714
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036098
# 10      10                                 addr_state:NY      0.057793
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12      12                                 addr_state:CA      0.063949
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078983
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136948
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101655
# 16      16                           addr_state:GA_WA_OR      0.185746
# 17      17                              addr_state:WI_MT      0.240456
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262768
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22      22              verification_status:Not Verified      0.084434
# 23      23           verification_status:Source Verified     -0.010560
# 24      24                           purpose:credit_card      0.300415
# 25      25                    purpose:debt_consolidation      0.197168
# 26      26                    purpose:oth__med__vacation      0.213265
# 27      27           purpose:major_purch__car__home_impr      0.265546
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078657
# 30      30                                  emp_length:1      0.099199
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125336
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425053
# 40      40                      mths_since_issue_d:53-64      0.178658
# 41      41                      mths_since_issue_d:65-84     -0.060625
# 42      42                               int_rate:<9.548      0.867403
# 43      43                         int_rate:9.548-12.025      0.540435
# 44      44                         int_rate:12.025-15.74      0.291230
# 45      45                         int_rate:15.74-20.281      0.103116
# 46      46           mths_since_earliest_cr_line:141-164      0.056439
# 47      47           mths_since_earliest_cr_line:165-247      0.038175
# 48      48           mths_since_earliest_cr_line:248-270      0.080625
# 49      49           mths_since_earliest_cr_line:271-352      0.122839
# 50      50              mths_since_earliest_cr_line:>352      0.131429
# 51      51                              inq_last_6mths:0      0.694464
# 52      52                            inq_last_6mths:1-2      0.547345
# 53      53                            inq_last_6mths:3-6      0.336631
# 54      54                            acc_now_delinq:>=1      0.235451
# 55      55                            annual_inc:20K-30K     -0.068940
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306246
# 61      61                            annual_inc:80K-90K      0.380309
# 62      62                           annual_inc:90K-100K      0.400762
# 63      63                          annual_inc:100K-120K      0.479392
# 64      64                          annual_inc:120K-140K      0.577041
# 65      65                              annual_inc:>140K      0.505299
# 66      66                                     dti:<=1.4      0.252541
# 67      67                                   dti:1.4-3.5      0.371493
# 68      68                                   dti:3.5-7.7      0.389216
# 69      69                                  dti:7.7-10.5      0.324627
# 70      70                                 dti:10.5-16.1      0.245253
# 71      71                                 dti:16.1-20.3      0.143907
# 72      72                                 dti:20.3-21.7      0.132742
# 73      73                                 dti:21.7-22.4      0.097492
# 74      74                                   dti:22.4-35      0.054606
# 75      75                mths_since_last_delinq:Missing      0.167526
# 76      76                   mths_since_last_delinq:4-30      0.192266
# 77      77                  mths_since_last_delinq:31-56      0.239033
# 78      78                   mths_since_last_delinq:>=57      0.191772
# 79      79                mths_since_last_record:Missing      0.102726
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135718
# 82      82                  mths_since_last_record:32-80      0.286681
# 83      83                  mths_since_last_record:81-86     -0.049878
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation
# 0         NaN                    Intercept           314.650086
# 1         NaN                        grade            89.100094
# 2         NaN                        grade            70.390995
# 3         NaN                        grade            55.235911
# 4         NaN                        grade            40.505119
# 5         NaN                        grade            26.390105
# 6         NaN                        grade            11.735332
# 7         NaN               home_ownership             7.225742
# 8         NaN               home_ownership             8.189834
# 9         NaN                   addr_state             2.783329
# 10        NaN                   addr_state             4.456060
# 11        NaN                   addr_state             4.613140
# 12        NaN                   addr_state             4.930748
# 13        NaN                   addr_state             6.089960
# 14        NaN                   addr_state            10.559279
# 15        NaN                   addr_state             7.838058
# 16        NaN                   addr_state            14.321777
# 17        NaN                   addr_state            18.540180
# 18        NaN                   addr_state            17.183651
# 19        NaN                   addr_state            20.260558
# 20        NaN                   addr_state            24.745089
# 21        NaN                   addr_state            40.417662
# 22        NaN          verification_status             6.510205
# 23        NaN          verification_status            -0.814248
# 24        NaN                      purpose            23.163234
# 25        NaN                      purpose            15.202517
# 26        NaN                      purpose            16.443648
# 27        NaN                      purpose            20.474683
# 28        NaN          initial_list_status             4.226872
# 29        NaN                         term             6.064820
# 30        NaN                   emp_length             7.648681
# 31        NaN                   emp_length             9.728529
# 32        NaN                   emp_length             7.049532
# 33        NaN                   emp_length             4.748764
# 34        NaN                   emp_length             9.663909
# 35        NaN           mths_since_issue_d            84.196953
# 36        NaN           mths_since_issue_d            68.671486
# 37        NaN           mths_since_issue_d            60.828946
# 38        NaN           mths_since_issue_d            45.272175
# 39        NaN           mths_since_issue_d            32.773341
# 40        NaN           mths_since_issue_d            13.775279
# 41        NaN           mths_since_issue_d            -4.674454
# 42        NaN                     int_rate            66.880402
# 43        NaN                     int_rate            41.669830
# 44        NaN                     int_rate            22.455025
# 45        NaN                     int_rate             7.950688
# 46        NaN  mths_since_earliest_cr_line             4.351721
# 47        NaN  mths_since_earliest_cr_line             2.943427
# 48        NaN  mths_since_earliest_cr_line             6.216501
# 49        NaN  mths_since_earliest_cr_line             9.471440
# 50        NaN  mths_since_earliest_cr_line            10.133767
# 51        NaN               inq_last_6mths            53.546082
# 52        NaN               inq_last_6mths            42.202630
# 53        NaN               inq_last_6mths            25.955679
# 54        NaN               acc_now_delinq            18.154267
# 55        NaN                   annual_inc            -5.315545
# 56        NaN                   annual_inc            -0.426663
# 57        NaN                   annual_inc             6.886185
# 58        NaN                   annual_inc            12.054096
# 59        NaN                   annual_inc            17.867807
# 60        NaN                   annual_inc            23.612852
# 61        NaN                   annual_inc            29.323448
# 62        NaN                   annual_inc            30.900409
# 63        NaN                   annual_inc            36.963119
# 64        NaN                   annual_inc            44.492291
# 65        NaN                   annual_inc            38.960709
# 66        NaN                          dti            19.471955
# 67        NaN                          dti            28.643708
# 68        NaN                          dti            30.010158
# 69        NaN                          dti            25.030146
# 70        NaN                          dti            18.910019
# 71        NaN                          dti            11.095855
# 72        NaN                          dti            10.234942
# 73        NaN                          dti             7.517056
# 74        NaN                          dti             4.210330
# 75        NaN       mths_since_last_delinq            12.916959
# 76        NaN       mths_since_last_delinq            14.824528
# 77        NaN       mths_since_last_delinq            18.430454
# 78        NaN       mths_since_last_delinq            14.786437
# 79        NaN       mths_since_last_record             7.920576
# 80        NaN       mths_since_last_record            16.408937
# 81        NaN       mths_since_last_record            10.464400
# 82        NaN       mths_since_last_record            22.104291
# 83        NaN       mths_since_last_record            -3.845839
# 84        NaN                        grade             0.000000
# 85        NaN               home_ownership             0.000000
# 86        NaN                   addr_state             0.000000
# 87        NaN          verification_status             0.000000
# 88        NaN                      purpose             0.000000
# 89        NaN          initial_list_status             0.000000
# 90        NaN                         term             0.000000
# 91        NaN                   emp_length             0.000000
# 92        NaN           mths_since_issue_d             0.000000
# 93        NaN                     int_rate             0.000000
# 94        NaN  mths_since_earliest_cr_line             0.000000
# 95        NaN               inq_last_6mths             0.000000
# 96        NaN               acc_now_delinq             0.000000
# 97        NaN                   annual_inc             0.000000
# 98        NaN                          dti             0.000000
# 99        NaN       mths_since_last_delinq             0.000000
# 100       NaN       mths_since_last_record             0.000000

# %%
df_scorecard['Score - Preliminary'] = df_scorecard['Score - Calculation'].round()
# We round the values of the 'Score - Calculation' column.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286571
# 1        1                                       grade:A      1.155580
# 2        2                                       grade:B      0.912933
# 3        3                                       grade:C      0.716380
# 4        4                                       grade:D      0.525330
# 5        5                                       grade:E      0.342265
# 6        6                                       grade:F      0.152201
# 7        7                            home_ownership:OWN      0.093714
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036098
# 10      10                                 addr_state:NY      0.057793
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12      12                                 addr_state:CA      0.063949
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078983
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136948
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101655
# 16      16                           addr_state:GA_WA_OR      0.185746
# 17      17                              addr_state:WI_MT      0.240456
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262768
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22      22              verification_status:Not Verified      0.084434
# 23      23           verification_status:Source Verified     -0.010560
# 24      24                           purpose:credit_card      0.300415
# 25      25                    purpose:debt_consolidation      0.197168
# 26      26                    purpose:oth__med__vacation      0.213265
# 27      27           purpose:major_purch__car__home_impr      0.265546
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078657
# 30      30                                  emp_length:1      0.099199
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125336
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425053
# 40      40                      mths_since_issue_d:53-64      0.178658
# 41      41                      mths_since_issue_d:65-84     -0.060625
# 42      42                               int_rate:<9.548      0.867403
# 43      43                         int_rate:9.548-12.025      0.540435
# 44      44                         int_rate:12.025-15.74      0.291230
# 45      45                         int_rate:15.74-20.281      0.103116
# 46      46           mths_since_earliest_cr_line:141-164      0.056439
# 47      47           mths_since_earliest_cr_line:165-247      0.038175
# 48      48           mths_since_earliest_cr_line:248-270      0.080625
# 49      49           mths_since_earliest_cr_line:271-352      0.122839
# 50      50              mths_since_earliest_cr_line:>352      0.131429
# 51      51                              inq_last_6mths:0      0.694464
# 52      52                            inq_last_6mths:1-2      0.547345
# 53      53                            inq_last_6mths:3-6      0.336631
# 54      54                            acc_now_delinq:>=1      0.235451
# 55      55                            annual_inc:20K-30K     -0.068940
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306246
# 61      61                            annual_inc:80K-90K      0.380309
# 62      62                           annual_inc:90K-100K      0.400762
# 63      63                          annual_inc:100K-120K      0.479392
# 64      64                          annual_inc:120K-140K      0.577041
# 65      65                              annual_inc:>140K      0.505299
# 66      66                                     dti:<=1.4      0.252541
# 67      67                                   dti:1.4-3.5      0.371493
# 68      68                                   dti:3.5-7.7      0.389216
# 69      69                                  dti:7.7-10.5      0.324627
# 70      70                                 dti:10.5-16.1      0.245253
# 71      71                                 dti:16.1-20.3      0.143907
# 72      72                                 dti:20.3-21.7      0.132742
# 73      73                                 dti:21.7-22.4      0.097492
# 74      74                                   dti:22.4-35      0.054606
# 75      75                mths_since_last_delinq:Missing      0.167526
# 76      76                   mths_since_last_delinq:4-30      0.192266
# 77      77                  mths_since_last_delinq:31-56      0.239033
# 78      78                   mths_since_last_delinq:>=57      0.191772
# 79      79                mths_since_last_record:Missing      0.102726
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135718
# 82      82                  mths_since_last_record:32-80      0.286681
# 83      83                  mths_since_last_record:81-86     -0.049878
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation  \
# 0         NaN                    Intercept           314.650086
# 1         NaN                        grade            89.100094
# 2         NaN                        grade            70.390995
# 3         NaN                        grade            55.235911
# 4         NaN                        grade            40.505119
# 5         NaN                        grade            26.390105
# 6         NaN                        grade            11.735332
# 7         NaN               home_ownership             7.225742
# 8         NaN               home_ownership             8.189834
# 9         NaN                   addr_state             2.783329
# 10        NaN                   addr_state             4.456060
# 11        NaN                   addr_state             4.613140
# 12        NaN                   addr_state             4.930748
# 13        NaN                   addr_state             6.089960
# 14        NaN                   addr_state            10.559279
# 15        NaN                   addr_state             7.838058
# 16        NaN                   addr_state            14.321777
# 17        NaN                   addr_state            18.540180
# 18        NaN                   addr_state            17.183651
# 19        NaN                   addr_state            20.260558
# 20        NaN                   addr_state            24.745089
# 21        NaN                   addr_state            40.417662
# 22        NaN          verification_status             6.510205
# 23        NaN          verification_status            -0.814248
# 24        NaN                      purpose            23.163234
# 25        NaN                      purpose            15.202517
# 26        NaN                      purpose            16.443648
# 27        NaN                      purpose            20.474683
# 28        NaN          initial_list_status             4.226872
# 29        NaN                         term             6.064820
# 30        NaN                   emp_length             7.648681
# 31        NaN                   emp_length             9.728529
# 32        NaN                   emp_length             7.049532
# 33        NaN                   emp_length             4.748764
# 34        NaN                   emp_length             9.663909
# 35        NaN           mths_since_issue_d            84.196953
# 36        NaN           mths_since_issue_d            68.671486
# 37        NaN           mths_since_issue_d            60.828946
# 38        NaN           mths_since_issue_d            45.272175
# 39        NaN           mths_since_issue_d            32.773341
# 40        NaN           mths_since_issue_d            13.775279
# 41        NaN           mths_since_issue_d            -4.674454
# 42        NaN                     int_rate            66.880402
# 43        NaN                     int_rate            41.669830
# 44        NaN                     int_rate            22.455025
# 45        NaN                     int_rate             7.950688
# 46        NaN  mths_since_earliest_cr_line             4.351721
# 47        NaN  mths_since_earliest_cr_line             2.943427
# 48        NaN  mths_since_earliest_cr_line             6.216501
# 49        NaN  mths_since_earliest_cr_line             9.471440
# 50        NaN  mths_since_earliest_cr_line            10.133767
# 51        NaN               inq_last_6mths            53.546082
# 52        NaN               inq_last_6mths            42.202630
# 53        NaN               inq_last_6mths            25.955679
# 54        NaN               acc_now_delinq            18.154267
# 55        NaN                   annual_inc            -5.315545
# 56        NaN                   annual_inc            -0.426663
# 57        NaN                   annual_inc             6.886185
# 58        NaN                   annual_inc            12.054096
# 59        NaN                   annual_inc            17.867807
# 60        NaN                   annual_inc            23.612852
# 61        NaN                   annual_inc            29.323448
# 62        NaN                   annual_inc            30.900409
# 63        NaN                   annual_inc            36.963119
# 64        NaN                   annual_inc            44.492291
# 65        NaN                   annual_inc            38.960709
# 66        NaN                          dti            19.471955
# 67        NaN                          dti            28.643708
# 68        NaN                          dti            30.010158
# 69        NaN                          dti            25.030146
# 70        NaN                          dti            18.910019
# 71        NaN                          dti            11.095855
# 72        NaN                          dti            10.234942
# 73        NaN                          dti             7.517056
# 74        NaN                          dti             4.210330
# 75        NaN       mths_since_last_delinq            12.916959
# 76        NaN       mths_since_last_delinq            14.824528
# 77        NaN       mths_since_last_delinq            18.430454
# 78        NaN       mths_since_last_delinq            14.786437
# 79        NaN       mths_since_last_record             7.920576
# 80        NaN       mths_since_last_record            16.408937
# 81        NaN       mths_since_last_record            10.464400
# 82        NaN       mths_since_last_record            22.104291
# 83        NaN       mths_since_last_record            -3.845839
# 84        NaN                        grade             0.000000
# 85        NaN               home_ownership             0.000000
# 86        NaN                   addr_state             0.000000
# 87        NaN          verification_status             0.000000
# 88        NaN                      purpose             0.000000
# 89        NaN          initial_list_status             0.000000
# 90        NaN                         term             0.000000
# 91        NaN                   emp_length             0.000000
# 92        NaN           mths_since_issue_d             0.000000
# 93        NaN                     int_rate             0.000000
# 94        NaN  mths_since_earliest_cr_line             0.000000
# 95        NaN               inq_last_6mths             0.000000
# 96        NaN               acc_now_delinq             0.000000
# 97        NaN                   annual_inc             0.000000
# 98        NaN                          dti             0.000000
# 99        NaN       mths_since_last_delinq             0.000000
# 100       NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary
# 0                  315.0
# 1                   89.0
# 2                   70.0
# 3                   55.0
# 4                   41.0
# 5                   26.0
# 6                   12.0
# 7                    7.0
# 8                    8.0
# 9                    3.0
# 10                   4.0
# 11                   5.0
# 12                   5.0
# 13                   6.0
# 14                  11.0
# 15                   8.0
# 16                  14.0
# 17                  19.0
# 18                  17.0
# 19                  20.0
# 20                  25.0
# 21                  40.0
# 22                   7.0
# 23                  -1.0
# 24                  23.0
# 25                  15.0
# 26                  16.0
# 27                  20.0
# 28                   4.0
# 29                   6.0
# 30                   8.0
# 31                  10.0
# 32                   7.0
# 33                   5.0
# 34                  10.0
# 35                  84.0
# 36                  69.0
# 37                  61.0
# 38                  45.0
# 39                  33.0
# 40                  14.0
# 41                  -5.0
# 42                  67.0
# 43                  42.0
# 44                  22.0
# 45                   8.0
# 46                   4.0
# 47                   3.0
# 48                   6.0
# 49                   9.0
# 50                  10.0
# 51                  54.0
# 52                  42.0
# 53                  26.0
# 54                  18.0
# 55                  -5.0
# 56                  -0.0
# 57                   7.0
# 58                  12.0
# 59                  18.0
# 60                  24.0
# 61                  29.0
# 62                  31.0
# 63                  37.0
# 64                  44.0
# 65                  39.0
# 66                  19.0
# 67                  29.0
# 68                  30.0
# 69                  25.0
# 70                  19.0
# 71                  11.0
# 72                  10.0
# 73                   8.0
# 74                   4.0
# 75                  13.0
# 76                  15.0
# 77                  18.0
# 78                  15.0
# 79                   8.0
# 80                  16.0
# 81                  10.0
# 82                  22.0
# 83                  -4.0
# 84                   0.0
# 85                   0.0
# 86                   0.0
# 87                   0.0
# 88                   0.0
# 89                   0.0
# 90                   0.0
# 91                   0.0
# 92                   0.0
# 93                   0.0
# 94                   0.0
# 95                   0.0
# 96                   0.0
# 97                   0.0
# 98                   0.0
# 99                   0.0
# 100                  0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].min().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Sums all minimum values.
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].max().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Sums all maximum values.
max_sum_score_prel
# Out:
# 849.0

# %%
# here we can see 849 bt we have set to 850 means 1 will add from the max score

# %%
# But in the video we have to add 1 (851); One has to be subtracted from the maximum score for one original variable. Which one? We'll evaluate based on differences.

# %%
df_scorecard['Difference'] = df_scorecard['Score - Preliminary'] - df_scorecard['Score - Calculation']
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286571
# 1        1                                       grade:A      1.155580
# 2        2                                       grade:B      0.912933
# 3        3                                       grade:C      0.716380
# 4        4                                       grade:D      0.525330
# 5        5                                       grade:E      0.342265
# 6        6                                       grade:F      0.152201
# 7        7                            home_ownership:OWN      0.093714
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036098
# 10      10                                 addr_state:NY      0.057793
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12      12                                 addr_state:CA      0.063949
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078983
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136948
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101655
# 16      16                           addr_state:GA_WA_OR      0.185746
# 17      17                              addr_state:WI_MT      0.240456
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262768
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22      22              verification_status:Not Verified      0.084434
# 23      23           verification_status:Source Verified     -0.010560
# 24      24                           purpose:credit_card      0.300415
# 25      25                    purpose:debt_consolidation      0.197168
# 26      26                    purpose:oth__med__vacation      0.213265
# 27      27           purpose:major_purch__car__home_impr      0.265546
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078657
# 30      30                                  emp_length:1      0.099199
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125336
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425053
# 40      40                      mths_since_issue_d:53-64      0.178658
# 41      41                      mths_since_issue_d:65-84     -0.060625
# 42      42                               int_rate:<9.548      0.867403
# 43      43                         int_rate:9.548-12.025      0.540435
# 44      44                         int_rate:12.025-15.74      0.291230
# 45      45                         int_rate:15.74-20.281      0.103116
# 46      46           mths_since_earliest_cr_line:141-164      0.056439
# 47      47           mths_since_earliest_cr_line:165-247      0.038175
# 48      48           mths_since_earliest_cr_line:248-270      0.080625
# 49      49           mths_since_earliest_cr_line:271-352      0.122839
# 50      50              mths_since_earliest_cr_line:>352      0.131429
# 51      51                              inq_last_6mths:0      0.694464
# 52      52                            inq_last_6mths:1-2      0.547345
# 53      53                            inq_last_6mths:3-6      0.336631
# 54      54                            acc_now_delinq:>=1      0.235451
# 55      55                            annual_inc:20K-30K     -0.068940
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306246
# 61      61                            annual_inc:80K-90K      0.380309
# 62      62                           annual_inc:90K-100K      0.400762
# 63      63                          annual_inc:100K-120K      0.479392
# 64      64                          annual_inc:120K-140K      0.577041
# 65      65                              annual_inc:>140K      0.505299
# 66      66                                     dti:<=1.4      0.252541
# 67      67                                   dti:1.4-3.5      0.371493
# 68      68                                   dti:3.5-7.7      0.389216
# 69      69                                  dti:7.7-10.5      0.324627
# 70      70                                 dti:10.5-16.1      0.245253
# 71      71                                 dti:16.1-20.3      0.143907
# 72      72                                 dti:20.3-21.7      0.132742
# 73      73                                 dti:21.7-22.4      0.097492
# 74      74                                   dti:22.4-35      0.054606
# 75      75                mths_since_last_delinq:Missing      0.167526
# 76      76                   mths_since_last_delinq:4-30      0.192266
# 77      77                  mths_since_last_delinq:31-56      0.239033
# 78      78                   mths_since_last_delinq:>=57      0.191772
# 79      79                mths_since_last_record:Missing      0.102726
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135718
# 82      82                  mths_since_last_record:32-80      0.286681
# 83      83                  mths_since_last_record:81-86     -0.049878
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation  \
# 0         NaN                    Intercept           314.650086
# 1         NaN                        grade            89.100094
# 2         NaN                        grade            70.390995
# 3         NaN                        grade            55.235911
# 4         NaN                        grade            40.505119
# 5         NaN                        grade            26.390105
# 6         NaN                        grade            11.735332
# 7         NaN               home_ownership             7.225742
# 8         NaN               home_ownership             8.189834
# 9         NaN                   addr_state             2.783329
# 10        NaN                   addr_state             4.456060
# 11        NaN                   addr_state             4.613140
# 12        NaN                   addr_state             4.930748
# 13        NaN                   addr_state             6.089960
# 14        NaN                   addr_state            10.559279
# 15        NaN                   addr_state             7.838058
# 16        NaN                   addr_state            14.321777
# 17        NaN                   addr_state            18.540180
# 18        NaN                   addr_state            17.183651
# 19        NaN                   addr_state            20.260558
# 20        NaN                   addr_state            24.745089
# 21        NaN                   addr_state            40.417662
# 22        NaN          verification_status             6.510205
# 23        NaN          verification_status            -0.814248
# 24        NaN                      purpose            23.163234
# 25        NaN                      purpose            15.202517
# 26        NaN                      purpose            16.443648
# 27        NaN                      purpose            20.474683
# 28        NaN          initial_list_status             4.226872
# 29        NaN                         term             6.064820
# 30        NaN                   emp_length             7.648681
# 31        NaN                   emp_length             9.728529
# 32        NaN                   emp_length             7.049532
# 33        NaN                   emp_length             4.748764
# 34        NaN                   emp_length             9.663909
# 35        NaN           mths_since_issue_d            84.196953
# 36        NaN           mths_since_issue_d            68.671486
# 37        NaN           mths_since_issue_d            60.828946
# 38        NaN           mths_since_issue_d            45.272175
# 39        NaN           mths_since_issue_d            32.773341
# 40        NaN           mths_since_issue_d            13.775279
# 41        NaN           mths_since_issue_d            -4.674454
# 42        NaN                     int_rate            66.880402
# 43        NaN                     int_rate            41.669830
# 44        NaN                     int_rate            22.455025
# 45        NaN                     int_rate             7.950688
# 46        NaN  mths_since_earliest_cr_line             4.351721
# 47        NaN  mths_since_earliest_cr_line             2.943427
# 48        NaN  mths_since_earliest_cr_line             6.216501
# 49        NaN  mths_since_earliest_cr_line             9.471440
# 50        NaN  mths_since_earliest_cr_line            10.133767
# 51        NaN               inq_last_6mths            53.546082
# 52        NaN               inq_last_6mths            42.202630
# 53        NaN               inq_last_6mths            25.955679
# 54        NaN               acc_now_delinq            18.154267
# 55        NaN                   annual_inc            -5.315545
# 56        NaN                   annual_inc            -0.426663
# 57        NaN                   annual_inc             6.886185
# 58        NaN                   annual_inc            12.054096
# 59        NaN                   annual_inc            17.867807
# 60        NaN                   annual_inc            23.612852
# 61        NaN                   annual_inc            29.323448
# 62        NaN                   annual_inc            30.900409
# 63        NaN                   annual_inc            36.963119
# 64        NaN                   annual_inc            44.492291
# 65        NaN                   annual_inc            38.960709
# 66        NaN                          dti            19.471955
# 67        NaN                          dti            28.643708
# 68        NaN                          dti            30.010158
# 69        NaN                          dti            25.030146
# 70        NaN                          dti            18.910019
# 71        NaN                          dti            11.095855
# 72        NaN                          dti            10.234942
# 73        NaN                          dti             7.517056
# 74        NaN                          dti             4.210330
# 75        NaN       mths_since_last_delinq            12.916959
# 76        NaN       mths_since_last_delinq            14.824528
# 77        NaN       mths_since_last_delinq            18.430454
# 78        NaN       mths_since_last_delinq            14.786437
# 79        NaN       mths_since_last_record             7.920576
# 80        NaN       mths_since_last_record            16.408937
# 81        NaN       mths_since_last_record            10.464400
# 82        NaN       mths_since_last_record            22.104291
# 83        NaN       mths_since_last_record            -3.845839
# 84        NaN                        grade             0.000000
# 85        NaN               home_ownership             0.000000
# 86        NaN                   addr_state             0.000000
# 87        NaN          verification_status             0.000000
# 88        NaN                      purpose             0.000000
# 89        NaN          initial_list_status             0.000000
# 90        NaN                         term             0.000000
# 91        NaN                   emp_length             0.000000
# 92        NaN           mths_since_issue_d             0.000000
# 93        NaN                     int_rate             0.000000
# 94        NaN  mths_since_earliest_cr_line             0.000000
# 95        NaN               inq_last_6mths             0.000000
# 96        NaN               acc_now_delinq             0.000000
# 97        NaN                   annual_inc             0.000000
# 98        NaN                          dti             0.000000
# 99        NaN       mths_since_last_delinq             0.000000
# 100       NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference
# 0                  315.0    0.349914
# 1                   89.0   -0.100094
# 2                   70.0   -0.390995
# 3                   55.0   -0.235911
# 4                   41.0    0.494881
# 5                   26.0   -0.390105
# 6                   12.0    0.264668
# 7                    7.0   -0.225742
# 8                    8.0   -0.189834
# 9                    3.0    0.216671
# 10                   4.0   -0.456060
# 11                   5.0    0.386860
# 12                   5.0    0.069252
# 13                   6.0   -0.089960
# 14                  11.0    0.440721
# 15                   8.0    0.161942
# 16                  14.0   -0.321777
# 17                  19.0    0.459820
# 18                  17.0   -0.183651
# 19                  20.0   -0.260558
# 20                  25.0    0.254911
# 21                  40.0   -0.417662
# 22                   7.0    0.489795
# 23                  -1.0   -0.185752
# 24                  23.0   -0.163234
# 25                  15.0   -0.202517
# 26                  16.0   -0.443648
# 27                  20.0   -0.474683
# 28                   4.0   -0.226872
# 29                   6.0   -0.064820
# 30                   8.0    0.351319
# 31                  10.0    0.271471
# 32                   7.0   -0.049532
# 33                   5.0    0.251236
# 34                  10.0    0.336091
# 35                  84.0   -0.196953
# 36                  69.0    0.328514
# 37                  61.0    0.171054
# 38                  45.0   -0.272175
# 39                  33.0    0.226659
# 40                  14.0    0.224721
# 41                  -5.0   -0.325546
# 42                  67.0    0.119598
# 43                  42.0    0.330170
# 44                  22.0   -0.455025
# 45                   8.0    0.049312
# 46                   4.0   -0.351721
# 47                   3.0    0.056573
# 48                   6.0   -0.216501
# 49                   9.0   -0.471440
# 50                  10.0   -0.133767
# 51                  54.0    0.453918
# 52                  42.0   -0.202630
# 53                  26.0    0.044321
# 54                  18.0   -0.154267
# 55                  -5.0    0.315545
# 56                  -0.0    0.426663
# 57                   7.0    0.113815
# 58                  12.0   -0.054096
# 59                  18.0    0.132193
# 60                  24.0    0.387148
# 61                  29.0   -0.323448
# 62                  31.0    0.099591
# 63                  37.0    0.036881
# 64                  44.0   -0.492291
# 65                  39.0    0.039291
# 66                  19.0   -0.471955
# 67                  29.0    0.356292
# 68                  30.0   -0.010158
# 69                  25.0   -0.030146
# 70                  19.0    0.089981
# 71                  11.0   -0.095855
# 72                  10.0   -0.234942
# 73                   8.0    0.482944
# 74                   4.0   -0.210330
# 75                  13.0    0.083041
# 76                  15.0    0.175472
# 77                  18.0   -0.430454
# 78                  15.0    0.213563
# 79                   8.0    0.079424
# 80                  16.0   -0.408937
# 81                  10.0   -0.464400
# 82                  22.0   -0.104291
# 83                  -4.0   -0.154161
# 84                   0.0    0.000000
# 85                   0.0    0.000000
# 86                   0.0    0.000000
# 87                   0.0    0.000000
# 88                   0.0    0.000000
# 89                   0.0    0.000000
# 90                   0.0    0.000000
# 91                   0.0    0.000000
# 92                   0.0    0.000000
# 93                   0.0    0.000000
# 94                   0.0    0.000000
# 95                   0.0    0.000000
# 96                   0.0    0.000000
# 97                   0.0    0.000000
# 98                   0.0    0.000000
# 99                   0.0    0.000000
# 100                  0.0    0.000000

# %%
#we have to check which segment we can add or substract to optain optimal value
df_scorecard['Score - Final'] = df_scorecard['Score - Preliminary']
df_scorecard['Score - Final'][64] = 45
df_scorecard
# Out:
# C:\Users\om\AppData\Local\Temp\ipykernel_23292\1597543261.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Final'][64] = 45
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286571
# 1        1                                       grade:A      1.155580
# 2        2                                       grade:B      0.912933
# 3        3                                       grade:C      0.716380
# 4        4                                       grade:D      0.525330
# 5        5                                       grade:E      0.342265
# 6        6                                       grade:F      0.152201
# 7        7                            home_ownership:OWN      0.093714
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036098
# 10      10                                 addr_state:NY      0.057793
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12      12                                 addr_state:CA      0.063949
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078983
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136948
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101655
# 16      16                           addr_state:GA_WA_OR      0.185746
# 17      17                              addr_state:WI_MT      0.240456
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262768
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22      22              verification_status:Not Verified      0.084434
# 23      23           verification_status:Source Verified     -0.010560
# 24      24                           purpose:credit_card      0.300415
# 25      25                    purpose:debt_consolidation      0.197168
# 26      26                    purpose:oth__med__vacation      0.213265
# 27      27           purpose:major_purch__car__home_impr      0.265546
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078657
# 30      30                                  emp_length:1      0.099199
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125336
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425053
# 40      40                      mths_since_issue_d:53-64      0.178658
# 41      41                      mths_since_issue_d:65-84     -0.060625
# 42      42                               int_rate:<9.548      0.867403
# 43      43                         int_rate:9.548-12.025      0.540435
# 44      44                         int_rate:12.025-15.74      0.291230
# 45      45                         int_rate:15.74-20.281      0.103116
# 46      46           mths_since_earliest_cr_line:141-164      0.056439
# 47      47           mths_since_earliest_cr_line:165-247      0.038175
# 48      48           mths_since_earliest_cr_line:248-270      0.080625
# 49      49           mths_since_earliest_cr_line:271-352      0.122839
# 50      50              mths_since_earliest_cr_line:>352      0.131429
# 51      51                              inq_last_6mths:0      0.694464
# 52      52                            inq_last_6mths:1-2      0.547345
# 53      53                            inq_last_6mths:3-6      0.336631
# 54      54                            acc_now_delinq:>=1      0.235451
# 55      55                            annual_inc:20K-30K     -0.068940
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306246
# 61      61                            annual_inc:80K-90K      0.380309
# 62      62                           annual_inc:90K-100K      0.400762
# 63      63                          annual_inc:100K-120K      0.479392
# 64      64                          annual_inc:120K-140K      0.577041
# 65      65                              annual_inc:>140K      0.505299
# 66      66                                     dti:<=1.4      0.252541
# 67      67                                   dti:1.4-3.5      0.371493
# 68      68                                   dti:3.5-7.7      0.389216
# 69      69                                  dti:7.7-10.5      0.324627
# 70      70                                 dti:10.5-16.1      0.245253
# 71      71                                 dti:16.1-20.3      0.143907
# 72      72                                 dti:20.3-21.7      0.132742
# 73      73                                 dti:21.7-22.4      0.097492
# 74      74                                   dti:22.4-35      0.054606
# 75      75                mths_since_last_delinq:Missing      0.167526
# 76      76                   mths_since_last_delinq:4-30      0.192266
# 77      77                  mths_since_last_delinq:31-56      0.239033
# 78      78                   mths_since_last_delinq:>=57      0.191772
# 79      79                mths_since_last_record:Missing      0.102726
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135718
# 82      82                  mths_since_last_record:32-80      0.286681
# 83      83                  mths_since_last_record:81-86     -0.049878
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation  \
# 0         NaN                    Intercept           314.650086
# 1         NaN                        grade            89.100094
# 2         NaN                        grade            70.390995
# 3         NaN                        grade            55.235911
# 4         NaN                        grade            40.505119
# 5         NaN                        grade            26.390105
# 6         NaN                        grade            11.735332
# 7         NaN               home_ownership             7.225742
# 8         NaN               home_ownership             8.189834
# 9         NaN                   addr_state             2.783329
# 10        NaN                   addr_state             4.456060
# 11        NaN                   addr_state             4.613140
# 12        NaN                   addr_state             4.930748
# 13        NaN                   addr_state             6.089960
# 14        NaN                   addr_state            10.559279
# 15        NaN                   addr_state             7.838058
# 16        NaN                   addr_state            14.321777
# 17        NaN                   addr_state            18.540180
# 18        NaN                   addr_state            17.183651
# 19        NaN                   addr_state            20.260558
# 20        NaN                   addr_state            24.745089
# 21        NaN                   addr_state            40.417662
# 22        NaN          verification_status             6.510205
# 23        NaN          verification_status            -0.814248
# 24        NaN                      purpose            23.163234
# 25        NaN                      purpose            15.202517
# 26        NaN                      purpose            16.443648
# 27        NaN                      purpose            20.474683
# 28        NaN          initial_list_status             4.226872
# 29        NaN                         term             6.064820
# 30        NaN                   emp_length             7.648681
# 31        NaN                   emp_length             9.728529
# 32        NaN                   emp_length             7.049532
# 33        NaN                   emp_length             4.748764
# 34        NaN                   emp_length             9.663909
# 35        NaN           mths_since_issue_d            84.196953
# 36        NaN           mths_since_issue_d            68.671486
# 37        NaN           mths_since_issue_d            60.828946
# 38        NaN           mths_since_issue_d            45.272175
# 39        NaN           mths_since_issue_d            32.773341
# 40        NaN           mths_since_issue_d            13.775279
# 41        NaN           mths_since_issue_d            -4.674454
# 42        NaN                     int_rate            66.880402
# 43        NaN                     int_rate            41.669830
# 44        NaN                     int_rate            22.455025
# 45        NaN                     int_rate             7.950688
# 46        NaN  mths_since_earliest_cr_line             4.351721
# 47        NaN  mths_since_earliest_cr_line             2.943427
# 48        NaN  mths_since_earliest_cr_line             6.216501
# 49        NaN  mths_since_earliest_cr_line             9.471440
# 50        NaN  mths_since_earliest_cr_line            10.133767
# 51        NaN               inq_last_6mths            53.546082
# 52        NaN               inq_last_6mths            42.202630
# 53        NaN               inq_last_6mths            25.955679
# 54        NaN               acc_now_delinq            18.154267
# 55        NaN                   annual_inc            -5.315545
# 56        NaN                   annual_inc            -0.426663
# 57        NaN                   annual_inc             6.886185
# 58        NaN                   annual_inc            12.054096
# 59        NaN                   annual_inc            17.867807
# 60        NaN                   annual_inc            23.612852
# 61        NaN                   annual_inc            29.323448
# 62        NaN                   annual_inc            30.900409
# 63        NaN                   annual_inc            36.963119
# 64        NaN                   annual_inc            44.492291
# 65        NaN                   annual_inc            38.960709
# 66        NaN                          dti            19.471955
# 67        NaN                          dti            28.643708
# 68        NaN                          dti            30.010158
# 69        NaN                          dti            25.030146
# 70        NaN                          dti            18.910019
# 71        NaN                          dti            11.095855
# 72        NaN                          dti            10.234942
# 73        NaN                          dti             7.517056
# 74        NaN                          dti             4.210330
# 75        NaN       mths_since_last_delinq            12.916959
# 76        NaN       mths_since_last_delinq            14.824528
# 77        NaN       mths_since_last_delinq            18.430454
# 78        NaN       mths_since_last_delinq            14.786437
# 79        NaN       mths_since_last_record             7.920576
# 80        NaN       mths_since_last_record            16.408937
# 81        NaN       mths_since_last_record            10.464400
# 82        NaN       mths_since_last_record            22.104291
# 83        NaN       mths_since_last_record            -3.845839
# 84        NaN                        grade             0.000000
# 85        NaN               home_ownership             0.000000
# 86        NaN                   addr_state             0.000000
# 87        NaN          verification_status             0.000000
# 88        NaN                      purpose             0.000000
# 89        NaN          initial_list_status             0.000000
# 90        NaN                         term             0.000000
# 91        NaN                   emp_length             0.000000
# 92        NaN           mths_since_issue_d             0.000000
# 93        NaN                     int_rate             0.000000
# 94        NaN  mths_since_earliest_cr_line             0.000000
# 95        NaN               inq_last_6mths             0.000000
# 96        NaN               acc_now_delinq             0.000000
# 97        NaN                   annual_inc             0.000000
# 98        NaN                          dti             0.000000
# 99        NaN       mths_since_last_delinq             0.000000
# 100       NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  315.0    0.349914          315.0
# 1                   89.0   -0.100094           89.0
# 2                   70.0   -0.390995           70.0
# 3                   55.0   -0.235911           55.0
# 4                   41.0    0.494881           41.0
# 5                   26.0   -0.390105           26.0
# 6                   12.0    0.264668           12.0
# 7                    7.0   -0.225742            7.0
# 8                    8.0   -0.189834            8.0
# 9                    3.0    0.216671            3.0
# 10                   4.0   -0.456060            4.0
# 11                   5.0    0.386860            5.0
# 12                   5.0    0.069252            5.0
# 13                   6.0   -0.089960            6.0
# 14                  11.0    0.440721           11.0
# 15                   8.0    0.161942            8.0
# 16                  14.0   -0.321777           14.0
# 17                  19.0    0.459820           19.0
# 18                  17.0   -0.183651           17.0
# 19                  20.0   -0.260558           20.0
# 20                  25.0    0.254911           25.0
# 21                  40.0   -0.417662           40.0
# 22                   7.0    0.489795            7.0
# 23                  -1.0   -0.185752           -1.0
# 24                  23.0   -0.163234           23.0
# 25                  15.0   -0.202517           15.0
# 26                  16.0   -0.443648           16.0
# 27                  20.0   -0.474683           20.0
# 28                   4.0   -0.226872            4.0
# 29                   6.0   -0.064820            6.0
# 30                   8.0    0.351319            8.0
# 31                  10.0    0.271471           10.0
# 32                   7.0   -0.049532            7.0
# 33                   5.0    0.251236            5.0
# 34                  10.0    0.336091           10.0
# 35                  84.0   -0.196953           84.0
# 36                  69.0    0.328514           69.0
# 37                  61.0    0.171054           61.0
# 38                  45.0   -0.272175           45.0
# 39                  33.0    0.226659           33.0
# 40                  14.0    0.224721           14.0
# 41                  -5.0   -0.325546           -5.0
# 42                  67.0    0.119598           67.0
# 43                  42.0    0.330170           42.0
# 44                  22.0   -0.455025           22.0
# 45                   8.0    0.049312            8.0
# 46                   4.0   -0.351721            4.0
# 47                   3.0    0.056573            3.0
# 48                   6.0   -0.216501            6.0
# 49                   9.0   -0.471440            9.0
# 50                  10.0   -0.133767           10.0
# 51                  54.0    0.453918           54.0
# 52                  42.0   -0.202630           42.0
# 53                  26.0    0.044321           26.0
# 54                  18.0   -0.154267           18.0
# 55                  -5.0    0.315545           -5.0
# 56                  -0.0    0.426663           -0.0
# 57                   7.0    0.113815            7.0
# 58                  12.0   -0.054096           12.0
# 59                  18.0    0.132193           18.0
# 60                  24.0    0.387148           24.0
# 61                  29.0   -0.323448           29.0
# 62                  31.0    0.099591           31.0
# 63                  37.0    0.036881           37.0
# 64                  44.0   -0.492291           45.0
# 65                  39.0    0.039291           39.0
# 66                  19.0   -0.471955           19.0
# 67                  29.0    0.356292           29.0
# 68                  30.0   -0.010158           30.0
# 69                  25.0   -0.030146           25.0
# 70                  19.0    0.089981           19.0
# 71                  11.0   -0.095855           11.0
# 72                  10.0   -0.234942           10.0
# 73                   8.0    0.482944            8.0
# 74                   4.0   -0.210330            4.0
# 75                  13.0    0.083041           13.0
# 76                  15.0    0.175472           15.0
# 77                  18.0   -0.430454           18.0
# 78                  15.0    0.213563           15.0
# 79                   8.0    0.079424            8.0
# 80                  16.0   -0.408937           16.0
# 81                  10.0   -0.464400           10.0
# 82                  22.0   -0.104291           22.0
# 83                  -4.0   -0.154161           -4.0
# 84                   0.0    0.000000            0.0
# 85                   0.0    0.000000            0.0
# 86                   0.0    0.000000            0.0
# 87                   0.0    0.000000            0.0
# 88                   0.0    0.000000            0.0
# 89                   0.0    0.000000            0.0
# 90                   0.0    0.000000            0.0
# 91                   0.0    0.000000            0.0
# 92                   0.0    0.000000            0.0
# 93                   0.0    0.000000            0.0
# 94                   0.0    0.000000            0.0
# 95                   0.0    0.000000            0.0
# 96                   0.0    0.000000            0.0
# 97                   0.0    0.000000            0.0
# 98                   0.0    0.000000            0.0
# 99                   0.0    0.000000            0.0
# 100                  0.0    0.000000            0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].min().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Sums all minimum values.
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].max().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Sums all maximum values.
max_sum_score_prel
# Out:
# 850.0

# %% [markdown]
# ### Caclulating Credit Score

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 427211        1        0        0        0        0        0        0
# 206088        0        0        1        0        0        0        0
# 136020        1        0        0        0        0        0        0
# 412305        0        0        0        1        0        0        0
# 36159         0        0        1        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 427211                                   0                   0
# 206088                                   0                   0
# 136020                                   0                   0
# 412305                                   1                   0
# 36159                                    0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 427211                        1                                0
# 206088                        1                                0
# 136020                        1                                0
# 412305                        0                                0
# 36159                         1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 427211                 0              0                             0
# 206088                 0              0                             0
# 136020                 0              0                             0
# 412305                 0              0                             0
# 36159                  0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 427211              0                       0                          0
# 206088              0                       1                          0
# 136020              0                       0                          0
# 412305              0                       0                          0
# 36159               1                       0                          0
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 427211                          0                    0                 0
# 206088                          0                    0                 0
# 136020                          0                    1                 0
# 412305                          1                    0                 0
# 36159                           0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 427211              0                 0                             1
# 206088              0                 0                             0
# 136020              0                 0                             0
# 412305              0                 0                             0
# 36159               0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 427211                             0                                 0
# 206088                             0                                 1
# 136020                             0                                 0
# 412305                             0                                 0
# 36159                              0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 427211                                    1                             0
# 206088                                    0                             0
# 136020                                    0                             1
# 412305                                    1                             0
# 36159                                     0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 427211                                             0                    0
# 206088                                             0                    0
# 136020                                             0                    0
# 412305                                             0                    0
# 36159                                              1                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 427211                           1                           0
# 206088                           1                           0
# 136020                           1                           0
# 412305                           1                           0
# 36159                            0                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 427211                                    0                      1
# 206088                                    0                      1
# 136020                                    0                      1
# 412305                                    0                      1
# 36159                                     0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 427211                      0        1        0             0             0
# 206088                      0        1        0             0             0
# 136020                      0        1        0             0             0
# 412305                      0        1        0             0             0
# 36159                       0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 427211               1               0               0              0
# 206088               0               1               0              0
# 136020               0               0               0              1
# 412305               0               0               1              0
# 36159                0               1               0              0
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 427211                       0                         0
# 206088                       0                         0
# 136020                       0                         0
# 412305                       0                         0
# 36159                        0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 427211                         0                         1
# 206088                         0                         0
# 136020                         0                         0
# 412305                         0                         1
# 36159                          0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 427211                         0                         0
# 206088                         0                         1
# 136020                         0                         1
# 412305                         0                         0
# 36159                          0                         0
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 427211                         0                       0                1
# 206088                         0                       0                0
# 136020                         0                       0                1
# 412305                         0                       0                0
# 36159                          0                       1                0
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 427211                      0                      0                      0
# 206088                      0                      1                      0
# 136020                      0                      0                      0
# 412305                      0                      0                      1
# 36159                       0                      1                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 427211                 0                                 0
# 206088                 0                                 0
# 136020                 0                                 0
# 412305                 0                                 0
# 36159                  0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:165-247  \
# 427211                                    0
# 206088                                    1
# 136020                                    0
# 412305                                    1
# 36159                                     1
#
#         mths_since_earliest_cr_line:248-270  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 427211                                    0                                 1
# 206088                                    0                                 0
# 136020                                    1                                 0
# 412305                                    0                                 0
# 36159                                     0                                 0
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 427211                 0                   1                   0
# 206088                 0                   1                   0
# 136020                 0                   1                   0
# 412305                 0                   0                   1
# 36159                  0                   1                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 427211                  0                 1                   0
# 206088                  0                 1                   0
# 136020                  0                 1                   0
# 412305                  0                 1                   0
# 36159                   0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 427211                0                   0                   0
# 206088                0                   0                   0
# 136020                0                   0                   0
# 412305                0                   0                   0
# 36159                 0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 427211                   0                   0                   0
# 206088                   0                   0                   0
# 136020                   0                   0                   0
# 412305                   1                   0                   0
# 36159                    0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 427211                   1                   0                    0
# 206088                   0                   0                    0
# 136020                   0                   1                    0
# 412305                   0                   0                    0
# 36159                    0                   0                    1
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 427211                     0                     0                 0
# 206088                     1                     0                 0
# 136020                     0                     0                 0
# 412305                     0                     0                 0
# 36159                      0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 427211          0            0            0             0              0
# 206088          0            0            1             0              0
# 136020          0            0            0             0              1
# 412305          0            0            0             0              1
# 36159           0            0            0             0              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 427211              0              0              1            0        0
# 206088              0              0              0            0        0
# 136020              0              0              0            0        0
# 412305              0              0              0            0        0
# 36159               0              0              0            1        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 427211                               1                           0
# 206088                               0                           0
# 136020                               0                           0
# 412305                               0                           0
# 36159                                1                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 427211                           0                            0
# 206088                           0                            0
# 136020                           0                            0
# 412305                           0                            0
# 36159                            0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:81-86
# 427211                             0
# 206088                             0
# 136020                             0
# 412305                             0
# 36159                              0

# %%
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept     -1.286571
# 1        1                                       grade:A      1.155580
# 2        2                                       grade:B      0.912933
# 3        3                                       grade:C      0.716380
# 4        4                                       grade:D      0.525330
# 5        5                                       grade:E      0.342265
# 6        6                                       grade:F      0.152201
# 7        7                            home_ownership:OWN      0.093714
# 8        8                       home_ownership:MORTGAGE      0.106218
# 9        9                              addr_state:NM_VA      0.036098
# 10      10                                 addr_state:NY      0.057793
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC      0.059830
# 12      12                                 addr_state:CA      0.063949
# 13      13                        addr_state:UT_KY_AZ_NJ      0.078983
# 14      14                     addr_state:AR_MI_PA_OH_MN      0.136948
# 15      15                     addr_state:RI_MA_DE_SD_IN      0.101655
# 16      16                           addr_state:GA_WA_OR      0.185746
# 17      17                              addr_state:WI_MT      0.240456
# 18      18                                 addr_state:TX      0.222863
# 19      19                              addr_state:IL_CT      0.262768
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS      0.320930
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID      0.524195
# 22      22              verification_status:Not Verified      0.084434
# 23      23           verification_status:Source Verified     -0.010560
# 24      24                           purpose:credit_card      0.300415
# 25      25                    purpose:debt_consolidation      0.197168
# 26      26                    purpose:oth__med__vacation      0.213265
# 27      27           purpose:major_purch__car__home_impr      0.265546
# 28      28                         initial_list_status:w      0.054820
# 29      29                                       term:36      0.078657
# 30      30                                  emp_length:1      0.099199
# 31      31                                emp_length:2-4      0.126174
# 32      32                                emp_length:5-6      0.091429
# 33      33                                emp_length:7-9      0.061589
# 34      34                                 emp_length:10      0.125336
# 35      35                        mths_since_issue_d:<38      1.091989
# 36      36                      mths_since_issue_d:38-39      0.890632
# 37      37                      mths_since_issue_d:40-41      0.788919
# 38      38                      mths_since_issue_d:42-48      0.587156
# 39      39                      mths_since_issue_d:49-52      0.425053
# 40      40                      mths_since_issue_d:53-64      0.178658
# 41      41                      mths_since_issue_d:65-84     -0.060625
# 42      42                               int_rate:<9.548      0.867403
# 43      43                         int_rate:9.548-12.025      0.540435
# 44      44                         int_rate:12.025-15.74      0.291230
# 45      45                         int_rate:15.74-20.281      0.103116
# 46      46           mths_since_earliest_cr_line:141-164      0.056439
# 47      47           mths_since_earliest_cr_line:165-247      0.038175
# 48      48           mths_since_earliest_cr_line:248-270      0.080625
# 49      49           mths_since_earliest_cr_line:271-352      0.122839
# 50      50              mths_since_earliest_cr_line:>352      0.131429
# 51      51                              inq_last_6mths:0      0.694464
# 52      52                            inq_last_6mths:1-2      0.547345
# 53      53                            inq_last_6mths:3-6      0.336631
# 54      54                            acc_now_delinq:>=1      0.235451
# 55      55                            annual_inc:20K-30K     -0.068940
# 56      56                            annual_inc:30K-40K     -0.005534
# 57      57                            annual_inc:40K-50K      0.089310
# 58      58                            annual_inc:50K-60K      0.156335
# 59      59                            annual_inc:60K-70K      0.231736
# 60      60                            annual_inc:70K-80K      0.306246
# 61      61                            annual_inc:80K-90K      0.380309
# 62      62                           annual_inc:90K-100K      0.400762
# 63      63                          annual_inc:100K-120K      0.479392
# 64      64                          annual_inc:120K-140K      0.577041
# 65      65                              annual_inc:>140K      0.505299
# 66      66                                     dti:<=1.4      0.252541
# 67      67                                   dti:1.4-3.5      0.371493
# 68      68                                   dti:3.5-7.7      0.389216
# 69      69                                  dti:7.7-10.5      0.324627
# 70      70                                 dti:10.5-16.1      0.245253
# 71      71                                 dti:16.1-20.3      0.143907
# 72      72                                 dti:20.3-21.7      0.132742
# 73      73                                 dti:21.7-22.4      0.097492
# 74      74                                   dti:22.4-35      0.054606
# 75      75                mths_since_last_delinq:Missing      0.167526
# 76      76                   mths_since_last_delinq:4-30      0.192266
# 77      77                  mths_since_last_delinq:31-56      0.239033
# 78      78                   mths_since_last_delinq:>=57      0.191772
# 79      79                mths_since_last_record:Missing      0.102726
# 80      80                   mths_since_last_record:3-20      0.212815
# 81      81                  mths_since_last_record:21-31      0.135718
# 82      82                  mths_since_last_record:32-80      0.286681
# 83      83                  mths_since_last_record:81-86     -0.049878
# 84       0                                       grade:G      0.000000
# 85       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 86       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 87       3                  verification_status:Verified      0.000000
# 88       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 89       5                         initial_list_status:f      0.000000
# 90       6                                       term:60      0.000000
# 91       7                                  emp_length:0      0.000000
# 92       8                        mths_since_issue_d:>84      0.000000
# 93       9                              int_rate:>20.281      0.000000
# 94      10              mths_since_earliest_cr_line:<140      0.000000
# 95      11                             inq_last_6mths:>6      0.000000
# 96      12                              acc_now_delinq:0      0.000000
# 97      13                               annual_inc:<20K      0.000000
# 98      14                                       dti:>35      0.000000
# 99      15                    mths_since_last_delinq:0-3      0.000000
# 100     16                    mths_since_last_record:0-2      0.000000
#
#      p_values        Original feature name  Score - Calculation  \
# 0         NaN                    Intercept           314.650086
# 1         NaN                        grade            89.100094
# 2         NaN                        grade            70.390995
# 3         NaN                        grade            55.235911
# 4         NaN                        grade            40.505119
# 5         NaN                        grade            26.390105
# 6         NaN                        grade            11.735332
# 7         NaN               home_ownership             7.225742
# 8         NaN               home_ownership             8.189834
# 9         NaN                   addr_state             2.783329
# 10        NaN                   addr_state             4.456060
# 11        NaN                   addr_state             4.613140
# 12        NaN                   addr_state             4.930748
# 13        NaN                   addr_state             6.089960
# 14        NaN                   addr_state            10.559279
# 15        NaN                   addr_state             7.838058
# 16        NaN                   addr_state            14.321777
# 17        NaN                   addr_state            18.540180
# 18        NaN                   addr_state            17.183651
# 19        NaN                   addr_state            20.260558
# 20        NaN                   addr_state            24.745089
# 21        NaN                   addr_state            40.417662
# 22        NaN          verification_status             6.510205
# 23        NaN          verification_status            -0.814248
# 24        NaN                      purpose            23.163234
# 25        NaN                      purpose            15.202517
# 26        NaN                      purpose            16.443648
# 27        NaN                      purpose            20.474683
# 28        NaN          initial_list_status             4.226872
# 29        NaN                         term             6.064820
# 30        NaN                   emp_length             7.648681
# 31        NaN                   emp_length             9.728529
# 32        NaN                   emp_length             7.049532
# 33        NaN                   emp_length             4.748764
# 34        NaN                   emp_length             9.663909
# 35        NaN           mths_since_issue_d            84.196953
# 36        NaN           mths_since_issue_d            68.671486
# 37        NaN           mths_since_issue_d            60.828946
# 38        NaN           mths_since_issue_d            45.272175
# 39        NaN           mths_since_issue_d            32.773341
# 40        NaN           mths_since_issue_d            13.775279
# 41        NaN           mths_since_issue_d            -4.674454
# 42        NaN                     int_rate            66.880402
# 43        NaN                     int_rate            41.669830
# 44        NaN                     int_rate            22.455025
# 45        NaN                     int_rate             7.950688
# 46        NaN  mths_since_earliest_cr_line             4.351721
# 47        NaN  mths_since_earliest_cr_line             2.943427
# 48        NaN  mths_since_earliest_cr_line             6.216501
# 49        NaN  mths_since_earliest_cr_line             9.471440
# 50        NaN  mths_since_earliest_cr_line            10.133767
# 51        NaN               inq_last_6mths            53.546082
# 52        NaN               inq_last_6mths            42.202630
# 53        NaN               inq_last_6mths            25.955679
# 54        NaN               acc_now_delinq            18.154267
# 55        NaN                   annual_inc            -5.315545
# 56        NaN                   annual_inc            -0.426663
# 57        NaN                   annual_inc             6.886185
# 58        NaN                   annual_inc            12.054096
# 59        NaN                   annual_inc            17.867807
# 60        NaN                   annual_inc            23.612852
# 61        NaN                   annual_inc            29.323448
# 62        NaN                   annual_inc            30.900409
# 63        NaN                   annual_inc            36.963119
# 64        NaN                   annual_inc            44.492291
# 65        NaN                   annual_inc            38.960709
# 66        NaN                          dti            19.471955
# 67        NaN                          dti            28.643708
# 68        NaN                          dti            30.010158
# 69        NaN                          dti            25.030146
# 70        NaN                          dti            18.910019
# 71        NaN                          dti            11.095855
# 72        NaN                          dti            10.234942
# 73        NaN                          dti             7.517056
# 74        NaN                          dti             4.210330
# 75        NaN       mths_since_last_delinq            12.916959
# 76        NaN       mths_since_last_delinq            14.824528
# 77        NaN       mths_since_last_delinq            18.430454
# 78        NaN       mths_since_last_delinq            14.786437
# 79        NaN       mths_since_last_record             7.920576
# 80        NaN       mths_since_last_record            16.408937
# 81        NaN       mths_since_last_record            10.464400
# 82        NaN       mths_since_last_record            22.104291
# 83        NaN       mths_since_last_record            -3.845839
# 84        NaN                        grade             0.000000
# 85        NaN               home_ownership             0.000000
# 86        NaN                   addr_state             0.000000
# 87        NaN          verification_status             0.000000
# 88        NaN                      purpose             0.000000
# 89        NaN          initial_list_status             0.000000
# 90        NaN                         term             0.000000
# 91        NaN                   emp_length             0.000000
# 92        NaN           mths_since_issue_d             0.000000
# 93        NaN                     int_rate             0.000000
# 94        NaN  mths_since_earliest_cr_line             0.000000
# 95        NaN               inq_last_6mths             0.000000
# 96        NaN               acc_now_delinq             0.000000
# 97        NaN                   annual_inc             0.000000
# 98        NaN                          dti             0.000000
# 99        NaN       mths_since_last_delinq             0.000000
# 100       NaN       mths_since_last_record             0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  315.0    0.349914          315.0
# 1                   89.0   -0.100094           89.0
# 2                   70.0   -0.390995           70.0
# 3                   55.0   -0.235911           55.0
# 4                   41.0    0.494881           41.0
# 5                   26.0   -0.390105           26.0
# 6                   12.0    0.264668           12.0
# 7                    7.0   -0.225742            7.0
# 8                    8.0   -0.189834            8.0
# 9                    3.0    0.216671            3.0
# 10                   4.0   -0.456060            4.0
# 11                   5.0    0.386860            5.0
# 12                   5.0    0.069252            5.0
# 13                   6.0   -0.089960            6.0
# 14                  11.0    0.440721           11.0
# 15                   8.0    0.161942            8.0
# 16                  14.0   -0.321777           14.0
# 17                  19.0    0.459820           19.0
# 18                  17.0   -0.183651           17.0
# 19                  20.0   -0.260558           20.0
# 20                  25.0    0.254911           25.0
# 21                  40.0   -0.417662           40.0
# 22                   7.0    0.489795            7.0
# 23                  -1.0   -0.185752           -1.0
# 24                  23.0   -0.163234           23.0
# 25                  15.0   -0.202517           15.0
# 26                  16.0   -0.443648           16.0
# 27                  20.0   -0.474683           20.0
# 28                   4.0   -0.226872            4.0
# 29                   6.0   -0.064820            6.0
# 30                   8.0    0.351319            8.0
# 31                  10.0    0.271471           10.0
# 32                   7.0   -0.049532            7.0
# 33                   5.0    0.251236            5.0
# 34                  10.0    0.336091           10.0
# 35                  84.0   -0.196953           84.0
# 36                  69.0    0.328514           69.0
# 37                  61.0    0.171054           61.0
# 38                  45.0   -0.272175           45.0
# 39                  33.0    0.226659           33.0
# 40                  14.0    0.224721           14.0
# 41                  -5.0   -0.325546           -5.0
# 42                  67.0    0.119598           67.0
# 43                  42.0    0.330170           42.0
# 44                  22.0   -0.455025           22.0
# 45                   8.0    0.049312            8.0
# 46                   4.0   -0.351721            4.0
# 47                   3.0    0.056573            3.0
# 48                   6.0   -0.216501            6.0
# 49                   9.0   -0.471440            9.0
# 50                  10.0   -0.133767           10.0
# 51                  54.0    0.453918           54.0
# 52                  42.0   -0.202630           42.0
# 53                  26.0    0.044321           26.0
# 54                  18.0   -0.154267           18.0
# 55                  -5.0    0.315545           -5.0
# 56                  -0.0    0.426663           -0.0
# 57                   7.0    0.113815            7.0
# 58                  12.0   -0.054096           12.0
# 59                  18.0    0.132193           18.0
# 60                  24.0    0.387148           24.0
# 61                  29.0   -0.323448           29.0
# 62                  31.0    0.099591           31.0
# 63                  37.0    0.036881           37.0
# 64                  44.0   -0.492291           45.0
# 65                  39.0    0.039291           39.0
# 66                  19.0   -0.471955           19.0
# 67                  29.0    0.356292           29.0
# 68                  30.0   -0.010158           30.0
# 69                  25.0   -0.030146           25.0
# 70                  19.0    0.089981           19.0
# 71                  11.0   -0.095855           11.0
# 72                  10.0   -0.234942           10.0
# 73                   8.0    0.482944            8.0
# 74                   4.0   -0.210330            4.0
# 75                  13.0    0.083041           13.0
# 76                  15.0    0.175472           15.0
# 77                  18.0   -0.430454           18.0
# 78                  15.0    0.213563           15.0
# 79                   8.0    0.079424            8.0
# 80                  16.0   -0.408937           16.0
# 81                  10.0   -0.464400           10.0
# 82                  22.0   -0.104291           22.0
# 83                  -4.0   -0.154161           -4.0
# 84                   0.0    0.000000            0.0
# 85                   0.0    0.000000            0.0
# 86                   0.0    0.000000            0.0
# 87                   0.0    0.000000            0.0
# 88                   0.0    0.000000            0.0
# 89                   0.0    0.000000            0.0
# 90                   0.0    0.000000            0.0
# 91                   0.0    0.000000            0.0
# 92                   0.0    0.000000            0.0
# 93                   0.0    0.000000            0.0
# 94                   0.0    0.000000            0.0
# 95                   0.0    0.000000            0.0
# 96                   0.0    0.000000            0.0
# 97                   0.0    0.000000            0.0
# 98                   0.0    0.000000            0.0
# 99                   0.0    0.000000            0.0
# 100                  0.0    0.000000            0.0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat

# %%
inputs_test_with_ref_cat_w_intercept.insert(0, 'Intercept', 1)
# We insert a column in the dataframe, with an index of 0, that is, in the beginning of the dataframe.
# The name of that column is 'Intercept', and its values are 1s.

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211          1        1        0        0        0        0        0
# 206088          1        0        0        1        0        0        0
# 136020          1        1        0        0        0        0        0
# 412305          1        0        0        0        1        0        0
# 36159           1        0        0        1        0        0        0
#
#         grade:G  home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 427211        0                                   0                   0
# 206088        0                                   0                   0
# 136020        0                                   0                   0
# 412305        0                                   1                   0
# 36159         0                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 427211                        1                                0
# 206088                        1                                0
# 136020                        1                                0
# 412305                        0                                0
# 36159                         1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 427211                 0              0                             0
# 206088                 0              0                             0
# 136020                 0              0                             0
# 412305                 0              0                             0
# 36159                  0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 427211              0                       0                          0
# 206088              0                       1                          0
# 136020              0                       0                          0
# 412305              0                       0                          0
# 36159               1                       0                          0
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 427211                          0                    0                 0
# 206088                          0                    0                 0
# 136020                          0                    1                 0
# 412305                          1                    0                 0
# 36159                           0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 427211              0                 0                             1
# 206088              0                 0                             0
# 136020              0                 0                             0
# 412305              0                 0                             0
# 36159               0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 427211                             0                                 0
# 206088                             0                                 1
# 136020                             0                                 0
# 412305                             0                                 0
# 36159                              0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 427211                                    1                             0
# 206088                                    0                             0
# 136020                                    0                             1
# 412305                                    1                             0
# 36159                                     0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 427211                                             0                    0
# 206088                                             0                    0
# 136020                                             0                    0
# 412305                                             0                    0
# 36159                                              1                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 427211                           1                           0
# 206088                           1                           0
# 136020                           1                           0
# 412305                           1                           0
# 36159                            0                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 427211                                    0                      1
# 206088                                    0                      1
# 136020                                    0                      1
# 412305                                    0                      1
# 36159                                     0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 427211                      0        1        0             0             0
# 206088                      0        1        0             0             0
# 136020                      0        1        0             0             0
# 412305                      0        1        0             0             0
# 36159                       0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 427211               1               0               0              0
# 206088               0               1               0              0
# 136020               0               0               0              1
# 412305               0               0               1              0
# 36159                0               1               0              0
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 427211                       0                         0
# 206088                       0                         0
# 136020                       0                         0
# 412305                       0                         0
# 36159                        0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 427211                         0                         1
# 206088                         0                         0
# 136020                         0                         0
# 412305                         0                         1
# 36159                          0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 427211                         0                         0
# 206088                         0                         1
# 136020                         0                         1
# 412305                         0                         0
# 36159                          0                         0
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 427211                         0                       0                1
# 206088                         0                       0                0
# 136020                         0                       0                1
# 412305                         0                       0                0
# 36159                          0                       1                0
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 427211                      0                      0                      0
# 206088                      0                      1                      0
# 136020                      0                      0                      0
# 412305                      0                      0                      1
# 36159                       0                      1                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 427211                 0                                 0
# 206088                 0                                 0
# 136020                 0                                 0
# 412305                 0                                 0
# 36159                  0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:165-247  \
# 427211                                    0
# 206088                                    1
# 136020                                    0
# 412305                                    1
# 36159                                     1
#
#         mths_since_earliest_cr_line:248-270  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 427211                                    0                                 1
# 206088                                    0                                 0
# 136020                                    1                                 0
# 412305                                    0                                 0
# 36159                                     0                                 0
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 427211                 0                   1                   0
# 206088                 0                   1                   0
# 136020                 0                   1                   0
# 412305                 0                   0                   1
# 36159                  0                   1                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 427211                  0                 1                   0
# 206088                  0                 1                   0
# 136020                  0                 1                   0
# 412305                  0                 1                   0
# 36159                   0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 427211                0                   0                   0
# 206088                0                   0                   0
# 136020                0                   0                   0
# 412305                0                   0                   0
# 36159                 0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 427211                   0                   0                   0
# 206088                   0                   0                   0
# 136020                   0                   0                   0
# 412305                   1                   0                   0
# 36159                    0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 427211                   1                   0                    0
# 206088                   0                   0                    0
# 136020                   0                   1                    0
# 412305                   0                   0                    0
# 36159                    0                   0                    1
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 427211                     0                     0                 0
# 206088                     1                     0                 0
# 136020                     0                     0                 0
# 412305                     0                     0                 0
# 36159                      0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 427211          0            0            0             0              0
# 206088          0            0            1             0              0
# 136020          0            0            0             0              1
# 412305          0            0            0             0              1
# 36159           0            0            0             0              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 427211              0              0              1            0        0
# 206088              0              0              0            0        0
# 136020              0              0              0            0        0
# 412305              0              0              0            0        0
# 36159               0              0              0            1        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 427211                               1                           0
# 206088                               0                           0
# 136020                               0                           0
# 412305                               0                           0
# 36159                                1                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 427211                           0                            0
# 206088                           0                            0
# 136020                           0                            0
# 412305                           0                            0
# 36159                            0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:81-86
# 427211                             0
# 206088                             0
# 136020                             0
# 412305                             0
# 36159                              0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat_w_intercept[df_scorecard['Feature name'].values]
# Here, from the 'inputs_test_with_ref_cat_w_intercept' dataframe, we keep only the columns with column names,
# exactly equal to the row values of the 'Feature name' column from the 'df_scorecard' dataframe.

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211          1        1        0        0        0        0        0
# 206088          1        0        0        1        0        0        0
# 136020          1        1        0        0        0        0        0
# 412305          1        0        0        0        1        0        0
# 36159           1        0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 427211              0                             0              0
# 206088              0                             0              0
# 136020              0                             0              0
# 412305              0                             0              0
# 36159               0                             0              1
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 427211                       0                          0
# 206088                       1                          0
# 136020                       0                          0
# 412305                       0                          0
# 36159                        0                          0
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 427211                          0                    0                 0
# 206088                          0                    0                 0
# 136020                          0                    1                 0
# 412305                          1                    0                 0
# 36159                           0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 427211              0                 0                             1
# 206088              0                 0                             0
# 136020              0                 0                             0
# 412305              0                 0                             0
# 36159               0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 427211                             0                                 0
# 206088                             0                                 1
# 136020                             0                                 0
# 412305                             0                                 0
# 36159                              0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 427211                                    1                    0
# 206088                                    0                    0
# 136020                                    0                    0
# 412305                                    1                    0
# 36159                                     0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 427211                           1                           0
# 206088                           1                           0
# 136020                           1                           0
# 412305                           1                           0
# 36159                            0                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 427211                                    0                      0        1
# 206088                                    0                      0        1
# 136020                                    0                      0        1
# 412305                                    0                      0        1
# 36159                                     0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 427211             0               1               0               0
# 206088             0               0               1               0
# 136020             0               0               0               0
# 412305             0               0               0               1
# 36159              0               0               1               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 427211              0                       0                         0
# 206088              0                       0                         0
# 136020              1                       0                         0
# 412305              0                       0                         0
# 36159               0                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 427211                         0                         1
# 206088                         0                         0
# 136020                         0                         0
# 412305                         0                         1
# 36159                          0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 427211                         0                         0
# 206088                         0                         1
# 136020                         0                         1
# 412305                         0                         0
# 36159                          0                         0
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 427211                         0                1                      0
# 206088                         0                0                      0
# 136020                         0                1                      0
# 412305                         0                0                      0
# 36159                          0                0                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 427211                      0                      0
# 206088                      1                      0
# 136020                      0                      0
# 412305                      0                      1
# 36159                       1                      0
#
#         mths_since_earliest_cr_line:141-164  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:165-247  \
# 427211                                    0
# 206088                                    1
# 136020                                    0
# 412305                                    1
# 36159                                     1
#
#         mths_since_earliest_cr_line:248-270  \
# 427211                                    0
# 206088                                    0
# 136020                                    0
# 412305                                    0
# 36159                                     0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 427211                                    0                                 1
# 206088                                    0                                 0
# 136020                                    1                                 0
# 412305                                    0                                 0
# 36159                                     0                                 0
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 427211                 0                   1                   0
# 206088                 0                   1                   0
# 136020                 0                   1                   0
# 412305                 0                   0                   1
# 36159                  0                   1                   0
#
#         acc_now_delinq:>=1  annual_inc:20K-30K  annual_inc:30K-40K  \
# 427211                   0                   0                   0
# 206088                   0                   0                   0
# 136020                   0                   0                   0
# 412305                   0                   0                   0
# 36159                    0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 427211                   0                   0                   0
# 206088                   0                   0                   0
# 136020                   0                   0                   0
# 412305                   1                   0                   0
# 36159                    0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 427211                   1                   0                    0
# 206088                   0                   0                    0
# 136020                   0                   1                    0
# 412305                   0                   0                    0
# 36159                    0                   0                    1
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 427211                     0                     0                 0
# 206088                     1                     0                 0
# 136020                     0                     0                 0
# 412305                     0                     0                 0
# 36159                      0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 427211          0            0            0             0              0
# 206088          0            0            1             0              0
# 136020          0            0            0             0              1
# 412305          0            0            0             0              1
# 36159           0            0            0             0              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 427211              0              0              1            0
# 206088              0              0              0            0
# 136020              0              0              0            0
# 412305              0              0              0            0
# 36159               0              0              0            1
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 427211                               1                            0
# 206088                               0                            1
# 136020                               0                            0
# 412305                               0                            1
# 36159                                1                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 427211                             0                            0
# 206088                             0                            0
# 136020                             1                            0
# 412305                             0                            0
# 36159                              0                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 427211                               1                            0
# 206088                               1                            0
# 136020                               1                            0
# 412305                               1                            0
# 36159                                1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:81-86  grade:G  \
# 427211                             0        0
# 206088                             0        0
# 136020                             0        0
# 412305                             0        0
# 36159                              0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 427211                                   0                                0
# 206088                                   0                                0
# 136020                                   0                                0
# 412305                                   1                                0
# 36159                                    0                                0
#
#         verification_status:Verified  \
# 427211                             0
# 206088                             0
# 136020                             1
# 412305                             0
# 36159                              1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  initial_list_status:f  \
# 427211                                             0                      1
# 206088                                             0                      1
# 136020                                             0                      1
# 412305                                             0                      1
# 36159                                              1                      1
#
#         term:60  emp_length:0  mths_since_issue_d:>84  int_rate:>20.281  \
# 427211        0             0                       0                 0
# 206088        0             0                       0                 0
# 136020        0             0                       0                 0
# 412305        0             0                       0                 0
# 36159         0             0                       1                 0
#
#         mths_since_earliest_cr_line:<140  inq_last_6mths:>6  acc_now_delinq:0  \
# 427211                                 0                  0                 1
# 206088                                 0                  0                 1
# 136020                                 0                  0                 1
# 412305                                 0                  0                 1
# 36159                                  0                  0                 1
#
#         annual_inc:<20K  dti:>35  mths_since_last_delinq:0-3  \
# 427211                0        0                           0
# 206088                0        0                           0
# 136020                0        0                           0
# 412305                0        0                           0
# 36159                 0        0                           0
#
#         mths_since_last_record:0-2
# 427211                           0
# 206088                           0
# 136020                           0
# 412305                           0
# 36159                            0

# %%
scorecard_scores = df_scorecard['Score - Final']

# %%
inputs_test_with_ref_cat_w_intercept.shape
# Out:
# (373028, 101)

# %%
scorecard_scores.shape
# Out:
# (101,)

# %%
scorecard_scores = scorecard_scores.values.reshape(101, 1)

# %%
scorecard_scores.shape
# Out:
# (101, 1)

# %%
y_scores = inputs_test_with_ref_cat_w_intercept.dot(scorecard_scores)
# Here we multiply the values of each row of the dataframe by the values of each column of the variable,
# which is an argument of the 'dot' method, and sum them. It's essentially the sum of the products.

# %%
y_scores.head()
# Out:
#             0
# 427211  684.0
# 206088  590.0
# 136020  663.0
# 412305  520.0
# 36159   519.0

# %%
y_scores.tail()
# Out:
#             0
# 259178  732.0
# 365838  597.0
# 131932  606.0
# 146867  599.0
# 121958  594.0

# %% [markdown]
# ### From Credit Score to PD

# %%
sum_coef_from_score = ((y_scores - min_score) / (max_score - min_score)) * (max_sum_coef - min_sum_coef) + min_sum_coef
# We divide the difference between the scores and the minimum score by
# the difference between the maximum score and the minimum score.
# Then, we multiply that by the difference between the maximum sum of coefficients and the minimum sum of coefficients.
# Then, we add the minimum sum of coefficients.

# %%
y_hat_proba_from_score = np.exp(sum_coef_from_score) / (np.exp(sum_coef_from_score) + 1)
# Here we divide an exponent raised to sum of coefficients from score by
# an exponent raised to sum of coefficients from score plus one.
y_hat_proba_from_score.head()
# Out:
#                0
# 427211  0.970793
# 206088  0.907591
# 136020  0.961997
# 412305  0.798462
# 36159   0.796366

# %%
y_hat_test_proba[0: 5]
# Out:
# array([0.97054287, 0.90768621, 0.96251831, 0.79606846, 0.79777258])

# %%
df_actual_predicted_probs['y_hat_test_proba'].head()
# Out:
# 0    0.353998
# 1    0.381585
# 2    0.386908
# 3    0.393532
# 4    0.398213
# Name: y_hat_test_proba, dtype: float64

# %% [markdown]
# ### Setting Cut-offs

# %%
# We need the confusion matrix again.
#np.where(np.squeeze(np.array(loan_data_targets_test)) == np.where(y_hat_test_proba >= tr, 1, 0), 1, 0).sum() / loan_data_targets_test.shape[0]
tr = 0.9
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)
#df_actual_predicted_probs['loan_data_targets_test'] == np.where(df_actual_predicted_probs['y_hat_test_proba'] >= tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted       0       1
# Actual
# 0           29191   11587
# 1          143094  189156

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted         0         1
# Actual
# 0          0.078254  0.031062
# 1          0.383601  0.507083

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.585336757562435

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99992643, 0.99992643,
#         1.        ]),
#  array([0.00000000e+00, 3.00978179e-06, 1.23401053e-04, ...,
#         9.99996990e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([       inf, 0.99270378, 0.99081153, ..., 0.39821331, 0.39353225,
#         0.35399808]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
thresholds
# Out:
# array([       inf, 0.99270378, 0.99081153, ..., 0.39821331, 0.39353225,
#        0.35399808])

# %%
thresholds.shape
# Out:
# (71168,)

# %%
df_cutoffs = pd.concat([pd.DataFrame(thresholds), pd.DataFrame(fpr), pd.DataFrame(tpr)], axis = 1)
# We concatenate 3 dataframes along the columns.

# %%
df_cutoffs.columns = ['thresholds', 'fpr', 'tpr']
# We name the columns of the dataframe 'thresholds', 'fpr', and 'tpr'.

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr
# 0         inf  0.000000  0.000000
# 1    0.992704  0.000000  0.000003
# 2    0.990812  0.000000  0.000123
# 3    0.990796  0.000025  0.000123
# 4    0.990042  0.000025  0.000283

# %%
df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)
# Let the first threshold (the value of the thresholds column with index 0) be equal to a number, very close to 1
# but smaller than 1, say 1 - 1 / 10 ^ 16.

# %%
df_cutoffs['Score'] = ((np.log(df_cutoffs['thresholds'] / (1 - df_cutoffs['thresholds'])) - min_sum_coef) * ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()
# The score corresponsing to each threshold equals:
# The the difference between the natural logarithm of the ratio of the threshold and 1 minus the threshold and
# the minimum sum of coefficients
# multiplied by
# the sum of the minimum score and the ratio of the difference between the maximum score and minimum score and 
# the difference between the maximum sum of coefficients and the minimum sum of coefficients.

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr   Score
# 0    1.000000  0.000000  0.000000  2060.0
# 1    0.992704  0.000000  0.000003   793.0
# 2    0.990812  0.000000  0.000123   775.0
# 3    0.990796  0.000025  0.000123   775.0
# 4    0.990042  0.000025  0.000283   768.0

# %%
df_cutoffs['Score'][0] = max_score

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score
# 0    1.000000  0.000000  0.000000  850.0
# 1    0.992704  0.000000  0.000003  793.0
# 2    0.990812  0.000000  0.000123  775.0
# 3    0.990796  0.000025  0.000123  775.0
# 4    0.990042  0.000025  0.000283  768.0

# %%
df_cutoffs.tail()
# Out:
#        thresholds       fpr       tpr  Score
# 71163    0.433847  0.999877  0.999988  393.0
# 71164    0.408861  0.999877  0.999997  385.0
# 71165    0.398213  0.999926  0.999997  382.0
# 71166    0.393532  0.999926  1.000000  381.0
# 71167    0.353998  1.000000  1.000000  367.0

# %%
# We define a function called 'n_approved' which assigns a value of 1 if a predicted probability
# is greater than the parameter p, which is a threshold, and a value of 0, if it is not.
# Then it sums the column.
# Thus, if given any percentage values, the function will return
# the number of rows wih estimated probabilites greater than the threshold. 
def n_approved(p):
    return np.where(df_actual_predicted_probs['y_hat_test_proba'] >= p, 1, 0).sum()

# %%
df_cutoffs['N Approved'] = df_cutoffs['thresholds'].apply(n_approved)
# Assuming that all credit applications above a given probability of being 'good' will be approved,
# when we apply the 'n_approved' function to a threshold, it will return the number of approved applications.
# Thus, here we calculate the number of approved appliations for al thresholds.
df_cutoffs['N Rejected'] = df_actual_predicted_probs['y_hat_test_proba'].shape[0] - df_cutoffs['N Approved']
# Then, we calculate the number of rejected applications for each threshold.
# It is the difference between the total number of applications and the approved applications for that threshold.
df_cutoffs['Approval Rate'] = df_cutoffs['N Approved'] / df_actual_predicted_probs['y_hat_test_proba'].shape[0]
# Approval rate equalts the ratio of the approved applications and all applications.
df_cutoffs['Rejection Rate'] = 1 - df_cutoffs['Approval Rate']
# Rejection rate equals one minus approval rate.

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score  N Approved  N Rejected  \
# 0    1.000000  0.000000  0.000000  850.0           0      373028
# 1    0.992704  0.000000  0.000003  793.0           1      373027
# 2    0.990812  0.000000  0.000123  775.0          41      372987
# 3    0.990796  0.000025  0.000123  775.0          42      372986
# 4    0.990042  0.000025  0.000283  768.0          95      372933
#
#    Approval Rate  Rejection Rate
# 0       0.000000        1.000000
# 1       0.000003        0.999997
# 2       0.000110        0.999890
# 3       0.000113        0.999887
# 4       0.000255        0.999745
